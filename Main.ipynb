# %% [markdown]
# ### Importing Libraries

# %%
import pandas as pd
import pymongo
from psycopg2 import sql
import psycopg2

# %% [markdown]
# ### MongoDB Connection to fetch data

# %%
renewable_client = pymongo.MongoClient("mongodb://localhost:27017/")

# %%
renewable_db = renewable_client["co2_renew_life_db"]

# %%
print(renewable_db)
# Out:
# Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'co2_renew_life_db')

# %%
renewable_collection = renewable_db["renewable_energy"]

# %%
renewable_all_records = renewable_collection.find()

# %%
print(renewable_all_records)
# Out:
# <pymongo.synchronous.cursor.Cursor object at 0x0000025CE37E3380>

# %%
for record in renewable_all_records:
    print(record)
# Out:
# {'_id': ObjectId('680625e5f5024b2c90d00ee1'), 'Entity': 'Africa', 'Code': nan, 'Year': 1965, 'Renewables (% equivalent primary energy)': 5.7402806}
# {'_id': ObjectId('680625e5f5024b2c90d00ee2'), 'Entity': 'Africa', 'Code': nan, 'Year': 1966, 'Renewables (% equivalent primary energy)': 6.1139693}
# {'_id': ObjectId('680625e5f5024b2c90d00ee3'), 'Entity': 'Africa', 'Code': nan, 'Year': 1967, 'Renewables (% equivalent primary energy)': 6.31658}
# {'_id': ObjectId('680625e5f5024b2c90d00ee4'), 'Entity': 'Africa', 'Code': nan, 'Year': 1968, 'Renewables (% equivalent primary energy)': 6.994845}
# {'_id': ObjectId('680625e5f5024b2c90d00ee5'), 'Entity': 'Africa', 'Code': nan, 'Year': 1969, 'Renewables (% equivalent primary energy)': 7.9439163}
# {'_id': ObjectId('680625e5f5024b2c90d00ee6'), 'Entity': 'Africa', 'Code': nan, 'Year': 1970, 'Renewables (% equivalent primary energy)': 9.148895}
# {'_id': ObjectId('680625e5f5024b2c90d00ee7'), 'Entity': 'Africa', 'Code': nan, 'Year': 1971, 'Renewables (% equivalent primary energy)': 8.124994}
# {'_id': ObjectId('680625e5f5024b2c90d00ee8'), 'Entity': 'Africa', 'Code': nan, 'Year': 1972, 'Renewables (% equivalent primary energy)': 8.747272}
# {'_id': ObjectId('680625e5f5024b2c90d00ee9'), 'Entity': 'Africa', 'Code': nan, 'Year': 1973, 'Renewables (% equivalent primary energy)': 8.54162}
# {'_id': ObjectId('680625e5f5024b2c90d00eea'), 'Entity': 'Africa', 'Code': nan, 'Year': 1974, 'Renewables (% equivalent primary energy)': 9.252387}
# {'_id': ObjectId('680625e5f5024b2c90d00eeb'), 'Entity': 'Africa', 'Code': nan, 'Year': 1975, 'Renewables (% equivalent primary energy)': 9.228769}
# {'_id': ObjectId('680625e5f5024b2c90d00eec'), 'Entity': 'Africa', 'Code': nan, 'Year': 1976, 'Renewables (% equivalent primary energy)': 9.41638}
# {'_id': ObjectId('680625e5f5024b2c90d00eed'), 'Entity': 'Africa', 'Code': nan, 'Year': 1977, 'Renewables (% equivalent primary energy)': 9.803094}
# {'_id': ObjectId('680625e5f5024b2c90d00eee'), 'Entity': 'Africa', 'Code': nan, 'Year': 1978, 'Renewables (% equivalent primary energy)': 9.518462}
# {'_id': ObjectId('680625e5f5024b2c90d00eef'), 'Entity': 'Africa', 'Code': nan, 'Year': 1979, 'Renewables (% equivalent primary energy)': 9.349527}
# {'_id': ObjectId('680625e5f5024b2c90d00ef0'), 'Entity': 'Africa', 'Code': nan, 'Year': 1980, 'Renewables (% equivalent primary energy)': 8.481442}
# {'_id': ObjectId('680625e5f5024b2c90d00ef1'), 'Entity': 'Africa', 'Code': nan, 'Year': 1981, 'Renewables (% equivalent primary energy)': 7.8527517}
# {'_id': ObjectId('680625e5f5024b2c90d00ef2'), 'Entity': 'Africa', 'Code': nan, 'Year': 1982, 'Renewables (% equivalent primary energy)': 7.3734274}
# {'_id': ObjectId('680625e5f5024b2c90d00ef3'), 'Entity': 'Africa', 'Code': nan, 'Year': 1983, 'Renewables (% equivalent primary energy)': 6.456112}
# {'_id': ObjectId('680625e5f5024b2c90d00ef4'), 'Entity': 'Africa', 'Code': nan, 'Year': 1984, 'Renewables (% equivalent primary energy)': 6.1585774}
# {'_id': ObjectId('680625e5f5024b2c90d00ef5'), 'Entity': 'Africa', 'Code': nan, 'Year': 1985, 'Renewables (% equivalent primary energy)': 6.5793424}
# {'_id': ObjectId('680625e5f5024b2c90d00ef6'), 'Entity': 'Africa', 'Code': nan, 'Year': 1986, 'Renewables (% equivalent primary energy)': 6.7159667}
# {'_id': ObjectId('680625e5f5024b2c90d00ef7'), 'Entity': 'Africa', 'Code': nan, 'Year': 1987, 'Renewables (% equivalent primary energy)': 6.243963}
# {'_id': ObjectId('680625e5f5024b2c90d00ef8'), 'Entity': 'Africa', 'Code': nan, 'Year': 1988, 'Renewables (% equivalent primary energy)': 6.3621163}
# {'_id': ObjectId('680625e5f5024b2c90d00ef9'), 'Entity': 'Africa', 'Code': nan, 'Year': 1989, 'Renewables (% equivalent primary energy)': 6.66546}
# {'_id': ObjectId('680625e5f5024b2c90d00efa'), 'Entity': 'Africa', 'Code': nan, 'Year': 1990, 'Renewables (% equivalent primary energy)': 6.5857716}
# {'_id': ObjectId('680625e5f5024b2c90d00efb'), 'Entity': 'Africa', 'Code': nan, 'Year': 1991, 'Renewables (% equivalent primary energy)': 6.9810143}
# {'_id': ObjectId('680625e5f5024b2c90d00efc'), 'Entity': 'Africa', 'Code': nan, 'Year': 1992, 'Renewables (% equivalent primary energy)': 6.5694675}
# {'_id': ObjectId('680625e5f5024b2c90d00efd'), 'Entity': 'Africa', 'Code': nan, 'Year': 1993, 'Renewables (% equivalent primary energy)': 6.43179}
# {'_id': ObjectId('680625e5f5024b2c90d00efe'), 'Entity': 'Africa', 'Code': nan, 'Year': 1994, 'Renewables (% equivalent primary energy)': 6.3092456}
# {'_id': ObjectId('680625e5f5024b2c90d00eff'), 'Entity': 'Africa', 'Code': nan, 'Year': 1995, 'Renewables (% equivalent primary energy)': 6.306244}
# {'_id': ObjectId('680625e5f5024b2c90d00f00'), 'Entity': 'Africa', 'Code': nan, 'Year': 1996, 'Renewables (% equivalent primary energy)': 6.4332542}
# {'_id': ObjectId('680625e5f5024b2c90d00f01'), 'Entity': 'Africa', 'Code': nan, 'Year': 1997, 'Renewables (% equivalent primary energy)': 6.465725}
# {'_id': ObjectId('680625e5f5024b2c90d00f02'), 'Entity': 'Africa', 'Code': nan, 'Year': 1998, 'Renewables (% equivalent primary energy)': 6.676159}
# {'_id': ObjectId('680625e5f5024b2c90d00f03'), 'Entity': 'Africa', 'Code': nan, 'Year': 1999, 'Renewables (% equivalent primary energy)': 6.858631}
# {'_id': ObjectId('680625e5f5024b2c90d00f04'), 'Entity': 'Africa', 'Code': nan, 'Year': 2000, 'Renewables (% equivalent primary energy)': 7.2029395}
# {'_id': ObjectId('680625e5f5024b2c90d00f05'), 'Entity': 'Africa', 'Code': nan, 'Year': 2001, 'Renewables (% equivalent primary energy)': 7.4362373}
# {'_id': ObjectId('680625e5f5024b2c90d00f06'), 'Entity': 'Africa', 'Code': nan, 'Year': 2002, 'Renewables (% equivalent primary energy)': 7.671944}
# {'_id': ObjectId('680625e5f5024b2c90d00f07'), 'Entity': 'Africa', 'Code': nan, 'Year': 2003, 'Renewables (% equivalent primary energy)': 7.105203}
# {'_id': ObjectId('680625e5f5024b2c90d00f08'), 'Entity': 'Africa', 'Code': nan, 'Year': 2004, 'Renewables (% equivalent primary energy)': 6.980063}
# {'_id': ObjectId('680625e5f5024b2c90d00f09'), 'Entity': 'Africa', 'Code': nan, 'Year': 2005, 'Renewables (% equivalent primary energy)': 7.0285006}
# {'_id': ObjectId('680625e5f5024b2c90d00f0a'), 'Entity': 'Africa', 'Code': nan, 'Year': 2006, 'Renewables (% equivalent primary energy)': 7.1611776}
# {'_id': ObjectId('680625e5f5024b2c90d00f0b'), 'Entity': 'Africa', 'Code': nan, 'Year': 2007, 'Renewables (% equivalent primary energy)': 7.0572457}
# {'_id': ObjectId('680625e5f5024b2c90d00f0c'), 'Entity': 'Africa', 'Code': nan, 'Year': 2008, 'Renewables (% equivalent primary energy)': 6.761787}
# {'_id': ObjectId('680625e5f5024b2c90d00f0d'), 'Entity': 'Africa', 'Code': nan, 'Year': 2009, 'Renewables (% equivalent primary energy)': 6.810709}
# {'_id': ObjectId('680625e5f5024b2c90d00f0e'), 'Entity': 'Africa', 'Code': nan, 'Year': 2010, 'Renewables (% equivalent primary energy)': 7.1290402}
# {'_id': ObjectId('680625e5f5024b2c90d00f0f'), 'Entity': 'Africa', 'Code': nan, 'Year': 2011, 'Renewables (% equivalent primary energy)': 7.2594023}
# {'_id': ObjectId('680625e5f5024b2c90d00f10'), 'Entity': 'Africa', 'Code': nan, 'Year': 2012, 'Renewables (% equivalent primary energy)': 6.9972486}
# {'_id': ObjectId('680625e5f5024b2c90d00f11'), 'Entity': 'Africa', 'Code': nan, 'Year': 2013, 'Renewables (% equivalent primary energy)': 7.189637}
# {'_id': ObjectId('680625e5f5024b2c90d00f12'), 'Entity': 'Africa', 'Code': nan, 'Year': 2014, 'Renewables (% equivalent primary energy)': 7.5156765}
# {'_id': ObjectId('680625e5f5024b2c90d00f13'), 'Entity': 'Africa', 'Code': nan, 'Year': 2015, 'Renewables (% equivalent primary energy)': 7.527505}
# {'_id': ObjectId('680625e5f5024b2c90d00f14'), 'Entity': 'Africa', 'Code': nan, 'Year': 2016, 'Renewables (% equivalent primary energy)': 7.404274}
# {'_id': ObjectId('680625e5f5024b2c90d00f15'), 'Entity': 'Africa', 'Code': nan, 'Year': 2017, 'Renewables (% equivalent primary energy)': 7.6419463}
# {'_id': ObjectId('680625e5f5024b2c90d00f16'), 'Entity': 'Africa', 'Code': nan, 'Year': 2018, 'Renewables (% equivalent primary energy)': 8.005552}
# {'_id': ObjectId('680625e5f5024b2c90d00f17'), 'Entity': 'Africa', 'Code': nan, 'Year': 2019, 'Renewables (% equivalent primary energy)': 8.356321}
# {'_id': ObjectId('680625e5f5024b2c90d00f18'), 'Entity': 'Africa', 'Code': nan, 'Year': 2020, 'Renewables (% equivalent primary energy)': 9.415897}
# {'_id': ObjectId('680625e5f5024b2c90d00f19'), 'Entity': 'Africa', 'Code': nan, 'Year': 2021, 'Renewables (% equivalent primary energy)': 9.152215}
# {'_id': ObjectId('680625e5f5024b2c90d00f1a'), 'Entity': 'Africa', 'Code': nan, 'Year': 2022, 'Renewables (% equivalent primary energy)': 9.298186}
# {'_id': ObjectId('680625e5f5024b2c90d00f1b'), 'Entity': 'Africa', 'Code': nan, 'Year': 2023, 'Renewables (% equivalent primary energy)': 9.826173}
# {'_id': ObjectId('680625e5f5024b2c90d00f1c'), 'Entity': 'Africa (EI)', 'Code': nan, 'Year': 1965, 'Renewables (% equivalent primary energy)': 5.7402806}
# {'_id': ObjectId('680625e5f5024b2c90d00f1d'), 'Entity': 'Africa (EI)', 'Code': nan, 'Year': 1966, 'Renewables (% equivalent primary energy)': 6.113969}
# {'_id': ObjectId('680625e5f5024b2c90d00f1e'), 'Entity': 'Africa (EI)', 'Code': nan, 'Year': 1967, 'Renewables (% equivalent primary energy)': 6.31658}
# {'_id': ObjectId('680625e5f5024b2c90d00f1f'), 'Entity': 'Africa (EI)', 'Code': nan, 'Year': 1968, 'Renewables (% equivalent primary energy)': 6.994845}
# {'_id': ObjectId('680625e5f5024b2c90d00f20'), 'Entity': 'Africa (EI)', 'Code': nan, 'Year': 1969, 'Renewables (% equivalent primary energy)': 7.9439154}
# {'_id': ObjectId('680625e5f5024b2c90d00f21'), 'Entity': 'Africa (EI)', 'Code': nan, 'Year': 1970, 'Renewables (% equivalent primary energy)': 9.148896}
# {'_id': ObjectId('680625e5f5024b2c90d00f22'), 'Entity': 'Africa (EI)', 'Code': nan, 'Year': 1971, 'Renewables (% equivalent primary energy)': 8.124996}
# {'_id': ObjectId('680625e5f5024b2c90d00f23'), 'Entity': 'Africa (EI)', 'Code': nan, 'Year': 1972, 'Renewables (% equivalent primary energy)': 8.7472725}
# {'_id': ObjectId('680625e5f5024b2c90d00f24'), 'Entity': 'Africa (EI)', 'Code': nan, 'Year': 1973, 'Renewables (% equivalent primary energy)': 8.54162}
# {'_id': ObjectId('680625e5f5024b2c90d00f25'), 'Entity': 'Africa (EI)', 'Code': nan, 'Year': 1974, 'Renewables (% equivalent primary energy)': 9.252388}
# {'_id': ObjectId('680625e5f5024b2c90d00f26'), 'Entity': 'Africa (EI)', 'Code': nan, 'Year': 1975, 'Renewables (% equivalent primary energy)': 9.228768}
# {'_id': ObjectId('680625e5f5024b2c90d00f27'), 'Entity': 'Africa (EI)', 'Code': nan, 'Year': 1976, 'Renewables (% equivalent primary energy)': 9.416379}
# {'_id': ObjectId('680625e5f5024b2c90d00f28'), 'Entity': 'Africa (EI)', 'Code': nan, 'Year': 1977, 'Renewables (% equivalent primary energy)': 9.803097}
# {'_id': ObjectId('680625e5f5024b2c90d00f29'), 'Entity': 'Africa (EI)', 'Code': nan, 'Year': 1978, 'Renewables (% equivalent primary energy)': 9.518462}
# {'_id': ObjectId('680625e5f5024b2c90d00f2a'), 'Entity': 'Africa (EI)', 'Code': nan, 'Year': 1979, 'Renewables (% equivalent primary energy)': 9.349527}
# {'_id': ObjectId('680625e5f5024b2c90d00f2b'), 'Entity': 'Africa (EI)', 'Code': nan, 'Year': 1980, 'Renewables (% equivalent primary energy)': 8.481442}
# {'_id': ObjectId('680625e5f5024b2c90d00f2c'), 'Entity': 'Africa (EI)', 'Code': nan, 'Year': 1981, 'Renewables (% equivalent primary energy)': 7.8527517}
# {'_id': ObjectId('680625e5f5024b2c90d00f2d'), 'Entity': 'Africa (EI)', 'Code': nan, 'Year': 1982, 'Renewables (% equivalent primary energy)': 7.3734274}
# {'_id': ObjectId('680625e5f5024b2c90d00f2e'), 'Entity': 'Africa (EI)', 'Code': nan, 'Year': 1983, 'Renewables (% equivalent primary energy)': 6.456112}
# {'_id': ObjectId('680625e5f5024b2c90d00f2f'), 'Entity': 'Africa (EI)', 'Code': nan, 'Year': 1984, 'Renewables (% equivalent primary energy)': 6.1585774}
# {'_id': ObjectId('680625e5f5024b2c90d00f30'), 'Entity': 'Africa (EI)', 'Code': nan, 'Year': 1985, 'Renewables (% equivalent primary energy)': 6.5793424}
# {'_id': ObjectId('680625e5f5024b2c90d00f31'), 'Entity': 'Africa (EI)', 'Code': nan, 'Year': 1986, 'Renewables (% equivalent primary energy)': 6.7159667}
# {'_id': ObjectId('680625e5f5024b2c90d00f32'), 'Entity': 'Africa (EI)', 'Code': nan, 'Year': 1987, 'Renewables (% equivalent primary energy)': 6.243963}
# {'_id': ObjectId('680625e5f5024b2c90d00f33'), 'Entity': 'Africa (EI)', 'Code': nan, 'Year': 1988, 'Renewables (% equivalent primary energy)': 6.3621163}
# {'_id': ObjectId('680625e5f5024b2c90d00f34'), 'Entity': 'Africa (EI)', 'Code': nan, 'Year': 1989, 'Renewables (% equivalent primary energy)': 6.6654606}
# {'_id': ObjectId('680625e5f5024b2c90d00f35'), 'Entity': 'Africa (EI)', 'Code': nan, 'Year': 1990, 'Renewables (% equivalent primary energy)': 6.5857716}
# {'_id': ObjectId('680625e5f5024b2c90d00f36'), 'Entity': 'Africa (EI)', 'Code': nan, 'Year': 1991, 'Renewables (% equivalent primary energy)': 6.9810143}
# {'_id': ObjectId('680625e5f5024b2c90d00f37'), 'Entity': 'Africa (EI)', 'Code': nan, 'Year': 1992, 'Renewables (% equivalent primary energy)': 6.5694675}
# {'_id': ObjectId('680625e5f5024b2c90d00f38'), 'Entity': 'Africa (EI)', 'Code': nan, 'Year': 1993, 'Renewables (% equivalent primary energy)': 6.43179}
# {'_id': ObjectId('680625e5f5024b2c90d00f39'), 'Entity': 'Africa (EI)', 'Code': nan, 'Year': 1994, 'Renewables (% equivalent primary energy)': 6.3092456}
# {'_id': ObjectId('680625e5f5024b2c90d00f3a'), 'Entity': 'Africa (EI)', 'Code': nan, 'Year': 1995, 'Renewables (% equivalent primary energy)': 6.306244}
# {'_id': ObjectId('680625e5f5024b2c90d00f3b'), 'Entity': 'Africa (EI)', 'Code': nan, 'Year': 1996, 'Renewables (% equivalent primary energy)': 6.433255}
# {'_id': ObjectId('680625e5f5024b2c90d00f3c'), 'Entity': 'Africa (EI)', 'Code': nan, 'Year': 1997, 'Renewables (% equivalent primary energy)': 6.465725}
# {'_id': ObjectId('680625e5f5024b2c90d00f3d'), 'Entity': 'Africa (EI)', 'Code': nan, 'Year': 1998, 'Renewables (% equivalent primary energy)': 6.6761603}
# {'_id': ObjectId('680625e5f5024b2c90d00f3e'), 'Entity': 'Africa (EI)', 'Code': nan, 'Year': 1999, 'Renewables (% equivalent primary energy)': 6.8586307}
# {'_id': ObjectId('680625e5f5024b2c90d00f3f'), 'Entity': 'Africa (EI)', 'Code': nan, 'Year': 2000, 'Renewables (% equivalent primary energy)': 7.2029395}
# {'_id': ObjectId('680625e5f5024b2c90d00f40'), 'Entity': 'Africa (EI)', 'Code': nan, 'Year': 2001, 'Renewables (% equivalent primary energy)': 7.436237}
# {'_id': ObjectId('680625e5f5024b2c90d00f41'), 'Entity': 'Africa (EI)', 'Code': nan, 'Year': 2002, 'Renewables (% equivalent primary energy)': 7.671944}
# {'_id': ObjectId('680625e5f5024b2c90d00f42'), 'Entity': 'Africa (EI)', 'Code': nan, 'Year': 2003, 'Renewables (% equivalent primary energy)': 7.105202}
# {'_id': ObjectId('680625e5f5024b2c90d00f43'), 'Entity': 'Africa (EI)', 'Code': nan, 'Year': 2004, 'Renewables (% equivalent primary energy)': 6.980063}
# {'_id': ObjectId('680625e5f5024b2c90d00f44'), 'Entity': 'Africa (EI)', 'Code': nan, 'Year': 2005, 'Renewables (% equivalent primary energy)': 7.0285006}
# {'_id': ObjectId('680625e5f5024b2c90d00f45'), 'Entity': 'Africa (EI)', 'Code': nan, 'Year': 2006, 'Renewables (% equivalent primary energy)': 7.161177}
# {'_id': ObjectId('680625e5f5024b2c90d00f46'), 'Entity': 'Africa (EI)', 'Code': nan, 'Year': 2007, 'Renewables (% equivalent primary energy)': 7.0572457}
# {'_id': ObjectId('680625e5f5024b2c90d00f47'), 'Entity': 'Africa (EI)', 'Code': nan, 'Year': 2008, 'Renewables (% equivalent primary energy)': 6.761787}
# {'_id': ObjectId('680625e5f5024b2c90d00f48'), 'Entity': 'Africa (EI)', 'Code': nan, 'Year': 2009, 'Renewables (% equivalent primary energy)': 6.8107085}
# {'_id': ObjectId('680625e5f5024b2c90d00f49'), 'Entity': 'Africa (EI)', 'Code': nan, 'Year': 2010, 'Renewables (% equivalent primary energy)': 7.12904}
# {'_id': ObjectId('680625e5f5024b2c90d00f4a'), 'Entity': 'Africa (EI)', 'Code': nan, 'Year': 2011, 'Renewables (% equivalent primary energy)': 7.2594023}
# {'_id': ObjectId('680625e5f5024b2c90d00f4b'), 'Entity': 'Africa (EI)', 'Code': nan, 'Year': 2012, 'Renewables (% equivalent primary energy)': 6.9972486}
# {'_id': ObjectId('680625e5f5024b2c90d00f4c'), 'Entity': 'Africa (EI)', 'Code': nan, 'Year': 2013, 'Renewables (% equivalent primary energy)': 7.189637}
# {'_id': ObjectId('680625e5f5024b2c90d00f4d'), 'Entity': 'Africa (EI)', 'Code': nan, 'Year': 2014, 'Renewables (% equivalent primary energy)': 7.5156765}
# {'_id': ObjectId('680625e5f5024b2c90d00f4e'), 'Entity': 'Africa (EI)', 'Code': nan, 'Year': 2015, 'Renewables (% equivalent primary energy)': 7.527505}
# {'_id': ObjectId('680625e5f5024b2c90d00f4f'), 'Entity': 'Africa (EI)', 'Code': nan, 'Year': 2016, 'Renewables (% equivalent primary energy)': 7.404273}
# {'_id': ObjectId('680625e5f5024b2c90d00f50'), 'Entity': 'Africa (EI)', 'Code': nan, 'Year': 2017, 'Renewables (% equivalent primary energy)': 7.6419473}
# {'_id': ObjectId('680625e5f5024b2c90d00f51'), 'Entity': 'Africa (EI)', 'Code': nan, 'Year': 2018, 'Renewables (% equivalent primary energy)': 8.005553}
# {'_id': ObjectId('680625e5f5024b2c90d00f52'), 'Entity': 'Africa (EI)', 'Code': nan, 'Year': 2019, 'Renewables (% equivalent primary energy)': 8.356321}
# {'_id': ObjectId('680625e5f5024b2c90d00f53'), 'Entity': 'Africa (EI)', 'Code': nan, 'Year': 2020, 'Renewables (% equivalent primary energy)': 9.415897}
# {'_id': ObjectId('680625e5f5024b2c90d00f54'), 'Entity': 'Africa (EI)', 'Code': nan, 'Year': 2021, 'Renewables (% equivalent primary energy)': 9.152214}
# {'_id': ObjectId('680625e5f5024b2c90d00f55'), 'Entity': 'Africa (EI)', 'Code': nan, 'Year': 2022, 'Renewables (% equivalent primary energy)': 9.298185}
# {'_id': ObjectId('680625e5f5024b2c90d00f56'), 'Entity': 'Africa (EI)', 'Code': nan, 'Year': 2023, 'Renewables (% equivalent primary energy)': 9.826172}
# {'_id': ObjectId('680625e5f5024b2c90d00f57'), 'Entity': 'Algeria', 'Code': 'DZA', 'Year': 1965, 'Renewables (% equivalent primary energy)': 4.7630677}
# {'_id': ObjectId('680625e5f5024b2c90d00f58'), 'Entity': 'Algeria', 'Code': 'DZA', 'Year': 1966, 'Renewables (% equivalent primary energy)': 3.518747}
# {'_id': ObjectId('680625e5f5024b2c90d00f59'), 'Entity': 'Algeria', 'Code': 'DZA', 'Year': 1967, 'Renewables (% equivalent primary energy)': 4.291954}
# {'_id': ObjectId('680625e5f5024b2c90d00f5a'), 'Entity': 'Algeria', 'Code': 'DZA', 'Year': 1968, 'Renewables (% equivalent primary energy)': 5.4861946}
# {'_id': ObjectId('680625e5f5024b2c90d00f5b'), 'Entity': 'Algeria', 'Code': 'DZA', 'Year': 1969, 'Renewables (% equivalent primary energy)': 3.1827633}
# {'_id': ObjectId('680625e5f5024b2c90d00f5c'), 'Entity': 'Algeria', 'Code': 'DZA', 'Year': 1970, 'Renewables (% equivalent primary energy)': 4.6656837}
# {'_id': ObjectId('680625e5f5024b2c90d00f5d'), 'Entity': 'Algeria', 'Code': 'DZA', 'Year': 1971, 'Renewables (% equivalent primary energy)': 2.4559188}
# {'_id': ObjectId('680625e5f5024b2c90d00f5e'), 'Entity': 'Algeria', 'Code': 'DZA', 'Year': 1972, 'Renewables (% equivalent primary energy)': 3.278343}
# {'_id': ObjectId('680625e5f5024b2c90d00f5f'), 'Entity': 'Algeria', 'Code': 'DZA', 'Year': 1973, 'Renewables (% equivalent primary energy)': 4.175826}
# {'_id': ObjectId('680625e5f5024b2c90d00f60'), 'Entity': 'Algeria', 'Code': 'DZA', 'Year': 1974, 'Renewables (% equivalent primary energy)': 2.494738}
# {'_id': ObjectId('680625e5f5024b2c90d00f61'), 'Entity': 'Algeria', 'Code': 'DZA', 'Year': 1975, 'Renewables (% equivalent primary energy)': 1.3782818}
# {'_id': ObjectId('680625e5f5024b2c90d00f62'), 'Entity': 'Algeria', 'Code': 'DZA', 'Year': 1976, 'Renewables (% equivalent primary energy)': 1.4010222}
# {'_id': ObjectId('680625e5f5024b2c90d00f63'), 'Entity': 'Algeria', 'Code': 'DZA', 'Year': 1977, 'Renewables (% equivalent primary energy)': 0.8817282}
# {'_id': ObjectId('680625e5f5024b2c90d00f64'), 'Entity': 'Algeria', 'Code': 'DZA', 'Year': 1978, 'Renewables (% equivalent primary energy)': 0.6521151}
# {'_id': ObjectId('680625e5f5024b2c90d00f65'), 'Entity': 'Algeria', 'Code': 'DZA', 'Year': 1979, 'Renewables (% equivalent primary energy)': 0.5792936}
# {'_id': ObjectId('680625e5f5024b2c90d00f66'), 'Entity': 'Algeria', 'Code': 'DZA', 'Year': 1980, 'Renewables (% equivalent primary energy)': 0.4290016}
# {'_id': ObjectId('680625e5f5024b2c90d00f67'), 'Entity': 'Algeria', 'Code': 'DZA', 'Year': 1981, 'Renewables (% equivalent primary energy)': 0.50294036}
# {'_id': ObjectId('680625e5f5024b2c90d00f68'), 'Entity': 'Algeria', 'Code': 'DZA', 'Year': 1982, 'Renewables (% equivalent primary energy)': 0.5708701}
# {'_id': ObjectId('680625e5f5024b2c90d00f69'), 'Entity': 'Algeria', 'Code': 'DZA', 'Year': 1983, 'Renewables (% equivalent primary energy)': 0.25644946}
# {'_id': ObjectId('680625e5f5024b2c90d00f6a'), 'Entity': 'Algeria', 'Code': 'DZA', 'Year': 1984, 'Renewables (% equivalent primary energy)': 0.5136736}
# {'_id': ObjectId('680625e5f5024b2c90d00f6b'), 'Entity': 'Algeria', 'Code': 'DZA', 'Year': 1985, 'Renewables (% equivalent primary energy)': 0.72826535}
# {'_id': ObjectId('680625e5f5024b2c90d00f6c'), 'Entity': 'Algeria', 'Code': 'DZA', 'Year': 1986, 'Renewables (% equivalent primary energy)': 0.2664045}
# {'_id': ObjectId('680625e5f5024b2c90d00f6d'), 'Entity': 'Algeria', 'Code': 'DZA', 'Year': 1987, 'Renewables (% equivalent primary energy)': 0.5174274}
# {'_id': ObjectId('680625e5f5024b2c90d00f6e'), 'Entity': 'Algeria', 'Code': 'DZA', 'Year': 1988, 'Renewables (% equivalent primary energy)': 0.17717436}
# {'_id': ObjectId('680625e5f5024b2c90d00f6f'), 'Entity': 'Algeria', 'Code': 'DZA', 'Year': 1989, 'Renewables (% equivalent primary energy)': 0.2249582}
# {'_id': ObjectId('680625e5f5024b2c90d00f70'), 'Entity': 'Algeria', 'Code': 'DZA', 'Year': 1990, 'Renewables (% equivalent primary energy)': 0.1267387}
# {'_id': ObjectId('680625e5f5024b2c90d00f71'), 'Entity': 'Algeria', 'Code': 'DZA', 'Year': 1991, 'Renewables (% equivalent primary energy)': 0.277607}
# {'_id': ObjectId('680625e5f5024b2c90d00f72'), 'Entity': 'Algeria', 'Code': 'DZA', 'Year': 1992, 'Renewables (% equivalent primary energy)': 0.18375748}
# {'_id': ObjectId('680625e5f5024b2c90d00f73'), 'Entity': 'Algeria', 'Code': 'DZA', 'Year': 1993, 'Renewables (% equivalent primary energy)': 0.35028014}
# {'_id': ObjectId('680625e5f5024b2c90d00f74'), 'Entity': 'Algeria', 'Code': 'DZA', 'Year': 1994, 'Renewables (% equivalent primary energy)': 0.16257899}
# {'_id': ObjectId('680625e5f5024b2c90d00f75'), 'Entity': 'Algeria', 'Code': 'DZA', 'Year': 1995, 'Renewables (% equivalent primary energy)': 0.18224756}
# {'_id': ObjectId('680625e5f5024b2c90d00f76'), 'Entity': 'Algeria', 'Code': 'DZA', 'Year': 1996, 'Renewables (% equivalent primary energy)': 0.1288034}
# {'_id': ObjectId('680625e5f5024b2c90d00f77'), 'Entity': 'Algeria', 'Code': 'DZA', 'Year': 1997, 'Renewables (% equivalent primary energy)': 0.074455895}
# {'_id': ObjectId('680625e5f5024b2c90d00f78'), 'Entity': 'Algeria', 'Code': 'DZA', 'Year': 1998, 'Renewables (% equivalent primary energy)': 0.20617963}
# {'_id': ObjectId('680625e5f5024b2c90d00f79'), 'Entity': 'Algeria', 'Code': 'DZA', 'Year': 1999, 'Renewables (% equivalent primary energy)': 0.1927434}
# {'_id': ObjectId('680625e5f5024b2c90d00f7a'), 'Entity': 'Algeria', 'Code': 'DZA', 'Year': 2000, 'Renewables (% equivalent primary energy)': 0.053235486}
# {'_id': ObjectId('680625e5f5024b2c90d00f7b'), 'Entity': 'Algeria', 'Code': 'DZA', 'Year': 2001, 'Renewables (% equivalent primary energy)': 0.065218486}
# {'_id': ObjectId('680625e5f5024b2c90d00f7c'), 'Entity': 'Algeria', 'Code': 'DZA', 'Year': 2002, 'Renewables (% equivalent primary energy)': 0.05167676}
# {'_id': ObjectId('680625e5f5024b2c90d00f7d'), 'Entity': 'Algeria', 'Code': 'DZA', 'Year': 2003, 'Renewables (% equivalent primary energy)': 0.228104}
# {'_id': ObjectId('680625e5f5024b2c90d00f7e'), 'Entity': 'Algeria', 'Code': 'DZA', 'Year': 2004, 'Renewables (% equivalent primary energy)': 0.2067869}
# {'_id': ObjectId('680625e5f5024b2c90d00f7f'), 'Entity': 'Algeria', 'Code': 'DZA', 'Year': 2005, 'Renewables (% equivalent primary energy)': 0.43411884}
# {'_id': ObjectId('680625e5f5024b2c90d00f80'), 'Entity': 'Algeria', 'Code': 'DZA', 'Year': 2006, 'Renewables (% equivalent primary energy)': 0.16327195}
# {'_id': ObjectId('680625e5f5024b2c90d00f81'), 'Entity': 'Algeria', 'Code': 'DZA', 'Year': 2007, 'Renewables (% equivalent primary energy)': 0.15990457}
# {'_id': ObjectId('680625e5f5024b2c90d00f82'), 'Entity': 'Algeria', 'Code': 'DZA', 'Year': 2008, 'Renewables (% equivalent primary energy)': 0.1877543}
# {'_id': ObjectId('680625e5f5024b2c90d00f83'), 'Entity': 'Algeria', 'Code': 'DZA', 'Year': 2009, 'Renewables (% equivalent primary energy)': 0.21278548}
# {'_id': ObjectId('680625e5f5024b2c90d00f84'), 'Entity': 'Algeria', 'Code': 'DZA', 'Year': 2010, 'Renewables (% equivalent primary energy)': 0.11513415}
# {'_id': ObjectId('680625e5f5024b2c90d00f85'), 'Entity': 'Algeria', 'Code': 'DZA', 'Year': 2011, 'Renewables (% equivalent primary energy)': 0.23525994}
# {'_id': ObjectId('680625e5f5024b2c90d00f86'), 'Entity': 'Algeria', 'Code': 'DZA', 'Year': 2012, 'Renewables (% equivalent primary energy)': 0.22453195}
# {'_id': ObjectId('680625e5f5024b2c90d00f87'), 'Entity': 'Algeria', 'Code': 'DZA', 'Year': 2013, 'Renewables (% equivalent primary energy)': 0.06476319}
# {'_id': ObjectId('680625e5f5024b2c90d00f88'), 'Entity': 'Algeria', 'Code': 'DZA', 'Year': 2014, 'Renewables (% equivalent primary energy)': 0.11750259}
# {'_id': ObjectId('680625e5f5024b2c90d00f89'), 'Entity': 'Algeria', 'Code': 'DZA', 'Year': 2015, 'Renewables (% equivalent primary energy)': 0.09681336}
# {'_id': ObjectId('680625e5f5024b2c90d00f8a'), 'Entity': 'Algeria', 'Code': 'DZA', 'Year': 2016, 'Renewables (% equivalent primary energy)': 0.14580713}
# {'_id': ObjectId('680625e5f5024b2c90d00f8b'), 'Entity': 'Algeria', 'Code': 'DZA', 'Year': 2017, 'Renewables (% equivalent primary energy)': 0.24701828}
# {'_id': ObjectId('680625e5f5024b2c90d00f8c'), 'Entity': 'Algeria', 'Code': 'DZA', 'Year': 2018, 'Renewables (% equivalent primary energy)': 0.28842947}
# {'_id': ObjectId('680625e5f5024b2c90d00f8d'), 'Entity': 'Algeria', 'Code': 'DZA', 'Year': 2019, 'Renewables (% equivalent primary energy)': 0.29497427}
# {'_id': ObjectId('680625e5f5024b2c90d00f8e'), 'Entity': 'Algeria', 'Code': 'DZA', 'Year': 2020, 'Renewables (% equivalent primary energy)': 0.30043116}
# {'_id': ObjectId('680625e5f5024b2c90d00f8f'), 'Entity': 'Algeria', 'Code': 'DZA', 'Year': 2021, 'Renewables (% equivalent primary energy)': 0.25285673}
# {'_id': ObjectId('680625e5f5024b2c90d00f90'), 'Entity': 'Algeria', 'Code': 'DZA', 'Year': 2022, 'Renewables (% equivalent primary energy)': 0.24182516}
# {'_id': ObjectId('680625e5f5024b2c90d00f91'), 'Entity': 'Algeria', 'Code': 'DZA', 'Year': 2023, 'Renewables (% equivalent primary energy)': 0.27036947}
# {'_id': ObjectId('680625e5f5024b2c90d00f92'), 'Entity': 'Argentina', 'Code': 'ARG', 'Year': 1965, 'Renewables (% equivalent primary energy)': 1.1026944}
# {'_id': ObjectId('680625e5f5024b2c90d00f93'), 'Entity': 'Argentina', 'Code': 'ARG', 'Year': 1966, 'Renewables (% equivalent primary energy)': 1.0818663}
# {'_id': ObjectId('680625e5f5024b2c90d00f94'), 'Entity': 'Argentina', 'Code': 'ARG', 'Year': 1967, 'Renewables (% equivalent primary energy)': 1.0765308}
# {'_id': ObjectId('680625e5f5024b2c90d00f95'), 'Entity': 'Argentina', 'Code': 'ARG', 'Year': 1968, 'Renewables (% equivalent primary energy)': 1.2272897}
# {'_id': ObjectId('680625e5f5024b2c90d00f96'), 'Entity': 'Argentina', 'Code': 'ARG', 'Year': 1969, 'Renewables (% equivalent primary energy)': 1.0651326}
# {'_id': ObjectId('680625e5f5024b2c90d00f97'), 'Entity': 'Argentina', 'Code': 'ARG', 'Year': 1970, 'Renewables (% equivalent primary energy)': 1.3533598}
# {'_id': ObjectId('680625e5f5024b2c90d00f98'), 'Entity': 'Argentina', 'Code': 'ARG', 'Year': 1971, 'Renewables (% equivalent primary energy)': 1.2702763}
# {'_id': ObjectId('680625e5f5024b2c90d00f99'), 'Entity': 'Argentina', 'Code': 'ARG', 'Year': 1972, 'Renewables (% equivalent primary energy)': 1.2349532}
# {'_id': ObjectId('680625e5f5024b2c90d00f9a'), 'Entity': 'Argentina', 'Code': 'ARG', 'Year': 1973, 'Renewables (% equivalent primary energy)': 2.2839267}
# {'_id': ObjectId('680625e5f5024b2c90d00f9b'), 'Entity': 'Argentina', 'Code': 'ARG', 'Year': 1974, 'Renewables (% equivalent primary energy)': 3.629566}
# {'_id': ObjectId('680625e5f5024b2c90d00f9c'), 'Entity': 'Argentina', 'Code': 'ARG', 'Year': 1975, 'Renewables (% equivalent primary energy)': 3.8664374}
# {'_id': ObjectId('680625e5f5024b2c90d00f9d'), 'Entity': 'Argentina', 'Code': 'ARG', 'Year': 1976, 'Renewables (% equivalent primary energy)': 3.5540857}
# {'_id': ObjectId('680625e5f5024b2c90d00f9e'), 'Entity': 'Argentina', 'Code': 'ARG', 'Year': 1977, 'Renewables (% equivalent primary energy)': 3.9090023}
# {'_id': ObjectId('680625e5f5024b2c90d00f9f'), 'Entity': 'Argentina', 'Code': 'ARG', 'Year': 1978, 'Renewables (% equivalent primary energy)': 5.227204}
# {'_id': ObjectId('680625e5f5024b2c90d00fa0'), 'Entity': 'Argentina', 'Code': 'ARG', 'Year': 1979, 'Renewables (% equivalent primary energy)': 6.702873}
# {'_id': ObjectId('680625e5f5024b2c90d00fa1'), 'Entity': 'Argentina', 'Code': 'ARG', 'Year': 1980, 'Renewables (% equivalent primary energy)': 9.552048}
# {'_id': ObjectId('680625e5f5024b2c90d00fa2'), 'Entity': 'Argentina', 'Code': 'ARG', 'Year': 1981, 'Renewables (% equivalent primary energy)': 9.542367}
# {'_id': ObjectId('680625e5f5024b2c90d00fa3'), 'Entity': 'Argentina', 'Code': 'ARG', 'Year': 1982, 'Renewables (% equivalent primary energy)': 11.229478}
# {'_id': ObjectId('680625e5f5024b2c90d00fa4'), 'Entity': 'Argentina', 'Code': 'ARG', 'Year': 1983, 'Renewables (% equivalent primary energy)': 11.313745}
# {'_id': ObjectId('680625e5f5024b2c90d00fa5'), 'Entity': 'Argentina', 'Code': 'ARG', 'Year': 1984, 'Renewables (% equivalent primary energy)': 12.136334}
# {'_id': ObjectId('680625e5f5024b2c90d00fa6'), 'Entity': 'Argentina', 'Code': 'ARG', 'Year': 1985, 'Renewables (% equivalent primary energy)': 12.759911}
# {'_id': ObjectId('680625e5f5024b2c90d00fa7'), 'Entity': 'Argentina', 'Code': 'ARG', 'Year': 1986, 'Renewables (% equivalent primary energy)': 12.297877}
# {'_id': ObjectId('680625e5f5024b2c90d00fa8'), 'Entity': 'Argentina', 'Code': 'ARG', 'Year': 1987, 'Renewables (% equivalent primary energy)': 12.24687}
# {'_id': ObjectId('680625e5f5024b2c90d00fa9'), 'Entity': 'Argentina', 'Code': 'ARG', 'Year': 1988, 'Renewables (% equivalent primary energy)': 8.416951}
# {'_id': ObjectId('680625e5f5024b2c90d00faa'), 'Entity': 'Argentina', 'Code': 'ARG', 'Year': 1989, 'Renewables (% equivalent primary energy)': 7.543206}
# {'_id': ObjectId('680625e5f5024b2c90d00fab'), 'Entity': 'Argentina', 'Code': 'ARG', 'Year': 1990, 'Renewables (% equivalent primary energy)': 10.29241}
# {'_id': ObjectId('680625e5f5024b2c90d00fac'), 'Entity': 'Argentina', 'Code': 'ARG', 'Year': 1991, 'Renewables (% equivalent primary energy)': 9.080978}
# {'_id': ObjectId('680625e5f5024b2c90d00fad'), 'Entity': 'Argentina', 'Code': 'ARG', 'Year': 1992, 'Renewables (% equivalent primary energy)': 10.2065}
# {'_id': ObjectId('680625e5f5024b2c90d00fae'), 'Entity': 'Argentina', 'Code': 'ARG', 'Year': 1993, 'Renewables (% equivalent primary energy)': 12.215968}
# {'_id': ObjectId('680625e5f5024b2c90d00faf'), 'Entity': 'Argentina', 'Code': 'ARG', 'Year': 1994, 'Renewables (% equivalent primary energy)': 13.306112}
# {'_id': ObjectId('680625e5f5024b2c90d00fb0'), 'Entity': 'Argentina', 'Code': 'ARG', 'Year': 1995, 'Renewables (% equivalent primary energy)': 12.535252}
# {'_id': ObjectId('680625e5f5024b2c90d00fb1'), 'Entity': 'Argentina', 'Code': 'ARG', 'Year': 1996, 'Renewables (% equivalent primary energy)': 10.224623}
# {'_id': ObjectId('680625e5f5024b2c90d00fb2'), 'Entity': 'Argentina', 'Code': 'ARG', 'Year': 1997, 'Renewables (% equivalent primary energy)': 12.513889}
# {'_id': ObjectId('680625e5f5024b2c90d00fb3'), 'Entity': 'Argentina', 'Code': 'ARG', 'Year': 1998, 'Renewables (% equivalent primary energy)': 11.481932}
# {'_id': ObjectId('680625e5f5024b2c90d00fb4'), 'Entity': 'Argentina', 'Code': 'ARG', 'Year': 1999, 'Renewables (% equivalent primary energy)': 9.2246065}
# {'_id': ObjectId('680625e5f5024b2c90d00fb5'), 'Entity': 'Argentina', 'Code': 'ARG', 'Year': 2000, 'Renewables (% equivalent primary energy)': 12.283152}
# {'_id': ObjectId('680625e5f5024b2c90d00fb6'), 'Entity': 'Argentina', 'Code': 'ARG', 'Year': 2001, 'Renewables (% equivalent primary energy)': 15.93624}
# {'_id': ObjectId('680625e5f5024b2c90d00fb7'), 'Entity': 'Argentina', 'Code': 'ARG', 'Year': 2002, 'Renewables (% equivalent primary energy)': 16.247978}
# {'_id': ObjectId('680625e5f5024b2c90d00fb8'), 'Entity': 'Argentina', 'Code': 'ARG', 'Year': 2003, 'Renewables (% equivalent primary energy)': 14.40661}
# {'_id': ObjectId('680625e5f5024b2c90d00fb9'), 'Entity': 'Argentina', 'Code': 'ARG', 'Year': 2004, 'Renewables (% equivalent primary energy)': 12.185576}
# {'_id': ObjectId('680625e5f5024b2c90d00fba'), 'Entity': 'Argentina', 'Code': 'ARG', 'Year': 2005, 'Renewables (% equivalent primary energy)': 12.790038}
# {'_id': ObjectId('680625e5f5024b2c90d00fbb'), 'Entity': 'Argentina', 'Code': 'ARG', 'Year': 2006, 'Renewables (% equivalent primary energy)': 13.449896}
# {'_id': ObjectId('680625e5f5024b2c90d00fbc'), 'Entity': 'Argentina', 'Code': 'ARG', 'Year': 2007, 'Renewables (% equivalent primary energy)': 10.613073}
# {'_id': ObjectId('680625e5f5024b2c90d00fbd'), 'Entity': 'Argentina', 'Code': 'ARG', 'Year': 2008, 'Renewables (% equivalent primary energy)': 10.447249}
# {'_id': ObjectId('680625e5f5024b2c90d00fbe'), 'Entity': 'Argentina', 'Code': 'ARG', 'Year': 2009, 'Renewables (% equivalent primary energy)': 11.797741}
# {'_id': ObjectId('680625e5f5024b2c90d00fbf'), 'Entity': 'Argentina', 'Code': 'ARG', 'Year': 2010, 'Renewables (% equivalent primary energy)': 11.650168}
# {'_id': ObjectId('680625e5f5024b2c90d00fc0'), 'Entity': 'Argentina', 'Code': 'ARG', 'Year': 2011, 'Renewables (% equivalent primary energy)': 10.914268}
# {'_id': ObjectId('680625e5f5024b2c90d00fc1'), 'Entity': 'Argentina', 'Code': 'ARG', 'Year': 2012, 'Renewables (% equivalent primary energy)': 10.176803}
# {'_id': ObjectId('680625e5f5024b2c90d00fc2'), 'Entity': 'Argentina', 'Code': 'ARG', 'Year': 2013, 'Renewables (% equivalent primary energy)': 10.940409}
# {'_id': ObjectId('680625e5f5024b2c90d00fc3'), 'Entity': 'Argentina', 'Code': 'ARG', 'Year': 2014, 'Renewables (% equivalent primary energy)': 11.038969}
# {'_id': ObjectId('680625e5f5024b2c90d00fc4'), 'Entity': 'Argentina', 'Code': 'ARG', 'Year': 2015, 'Renewables (% equivalent primary energy)': 10.89336}
# {'_id': ObjectId('680625e5f5024b2c90d00fc5'), 'Entity': 'Argentina', 'Code': 'ARG', 'Year': 2016, 'Renewables (% equivalent primary energy)': 10.17179}
# {'_id': ObjectId('680625e5f5024b2c90d00fc6'), 'Entity': 'Argentina', 'Code': 'ARG', 'Year': 2017, 'Renewables (% equivalent primary energy)': 10.979133}
# {'_id': ObjectId('680625e5f5024b2c90d00fc7'), 'Entity': 'Argentina', 'Code': 'ARG', 'Year': 2018, 'Renewables (% equivalent primary energy)': 11.331651}
# {'_id': ObjectId('680625e5f5024b2c90d00fc8'), 'Entity': 'Argentina', 'Code': 'ARG', 'Year': 2019, 'Renewables (% equivalent primary energy)': 11.911147}
# {'_id': ObjectId('680625e5f5024b2c90d00fc9'), 'Entity': 'Argentina', 'Code': 'ARG', 'Year': 2020, 'Renewables (% equivalent primary energy)': 12.310073}
# {'_id': ObjectId('680625e5f5024b2c90d00fca'), 'Entity': 'Argentina', 'Code': 'ARG', 'Year': 2021, 'Renewables (% equivalent primary energy)': 11.335143}
# {'_id': ObjectId('680625e5f5024b2c90d00fcb'), 'Entity': 'Argentina', 'Code': 'ARG', 'Year': 2022, 'Renewables (% equivalent primary energy)': 12.188763}
# {'_id': ObjectId('680625e5f5024b2c90d00fcc'), 'Entity': 'Argentina', 'Code': 'ARG', 'Year': 2023, 'Renewables (% equivalent primary energy)': 14.102216}
# {'_id': ObjectId('680625e5f5024b2c90d00fcd'), 'Entity': 'Asia', 'Code': nan, 'Year': 1965, 'Renewables (% equivalent primary energy)': 7.8735447}
# {'_id': ObjectId('680625e5f5024b2c90d00fce'), 'Entity': 'Asia', 'Code': nan, 'Year': 1966, 'Renewables (% equivalent primary energy)': 7.4938087}
# {'_id': ObjectId('680625e5f5024b2c90d00fcf'), 'Entity': 'Asia', 'Code': nan, 'Year': 1967, 'Renewables (% equivalent primary energy)': 6.7346387}
# {'_id': ObjectId('680625e5f5024b2c90d00fd0'), 'Entity': 'Asia', 'Code': nan, 'Year': 1968, 'Renewables (% equivalent primary energy)': 6.963028}
# {'_id': ObjectId('680625e5f5024b2c90d00fd1'), 'Entity': 'Asia', 'Code': nan, 'Year': 1969, 'Renewables (% equivalent primary energy)': 6.3012996}
# {'_id': ObjectId('680625e5f5024b2c90d00fd2'), 'Entity': 'Asia', 'Code': nan, 'Year': 1970, 'Renewables (% equivalent primary energy)': 5.661888}
# {'_id': ObjectId('680625e5f5024b2c90d00fd3'), 'Entity': 'Asia', 'Code': nan, 'Year': 1971, 'Renewables (% equivalent primary energy)': 5.6825113}
# {'_id': ObjectId('680625e5f5024b2c90d00fd4'), 'Entity': 'Asia', 'Code': nan, 'Year': 1972, 'Renewables (% equivalent primary energy)': 5.4817533}
# {'_id': ObjectId('680625e5f5024b2c90d00fd5'), 'Entity': 'Asia', 'Code': nan, 'Year': 1973, 'Renewables (% equivalent primary energy)': 4.7254024}
# {'_id': ObjectId('680625e5f5024b2c90d00fd6'), 'Entity': 'Asia', 'Code': nan, 'Year': 1974, 'Renewables (% equivalent primary energy)': 5.289435}
# {'_id': ObjectId('680625e5f5024b2c90d00fd7'), 'Entity': 'Asia', 'Code': nan, 'Year': 1975, 'Renewables (% equivalent primary energy)': 5.432976}
# {'_id': ObjectId('680625e5f5024b2c90d00fd8'), 'Entity': 'Asia', 'Code': nan, 'Year': 1976, 'Renewables (% equivalent primary energy)': 5.272847}
# {'_id': ObjectId('680625e5f5024b2c90d00fd9'), 'Entity': 'Asia', 'Code': nan, 'Year': 1977, 'Renewables (% equivalent primary energy)': 4.885452}
# {'_id': ObjectId('680625e5f5024b2c90d00fda'), 'Entity': 'Asia', 'Code': nan, 'Year': 1978, 'Renewables (% equivalent primary energy)': 4.842396}
# {'_id': ObjectId('680625e5f5024b2c90d00fdb'), 'Entity': 'Asia', 'Code': nan, 'Year': 1979, 'Renewables (% equivalent primary energy)': 5.0050187}
# {'_id': ObjectId('680625e5f5024b2c90d00fdc'), 'Entity': 'Asia', 'Code': nan, 'Year': 1980, 'Renewables (% equivalent primary energy)': 5.387261}
# {'_id': ObjectId('680625e5f5024b2c90d00fdd'), 'Entity': 'Asia', 'Code': nan, 'Year': 1981, 'Renewables (% equivalent primary energy)': 5.6962633}
# {'_id': ObjectId('680625e5f5024b2c90d00fde'), 'Entity': 'Asia', 'Code': nan, 'Year': 1982, 'Renewables (% equivalent primary energy)': 5.688111}
# {'_id': ObjectId('680625e5f5024b2c90d00fdf'), 'Entity': 'Asia', 'Code': nan, 'Year': 1983, 'Renewables (% equivalent primary energy)': 5.652118}
# {'_id': ObjectId('680625e5f5024b2c90d00fe0'), 'Entity': 'Asia', 'Code': nan, 'Year': 1984, 'Renewables (% equivalent primary energy)': 5.339281}
# {'_id': ObjectId('680625e5f5024b2c90d00fe1'), 'Entity': 'Asia', 'Code': nan, 'Year': 1985, 'Renewables (% equivalent primary energy)': 5.351906}
# {'_id': ObjectId('680625e5f5024b2c90d00fe2'), 'Entity': 'Asia', 'Code': nan, 'Year': 1986, 'Renewables (% equivalent primary energy)': 5.190978}
# {'_id': ObjectId('680625e5f5024b2c90d00fe3'), 'Entity': 'Asia', 'Code': nan, 'Year': 1987, 'Renewables (% equivalent primary energy)': 5.0590653}
# {'_id': ObjectId('680625e5f5024b2c90d00fe4'), 'Entity': 'Asia', 'Code': nan, 'Year': 1988, 'Renewables (% equivalent primary energy)': 5.4249687}
# {'_id': ObjectId('680625e5f5024b2c90d00fe5'), 'Entity': 'Asia', 'Code': nan, 'Year': 1989, 'Renewables (% equivalent primary energy)': 5.319675}
# {'_id': ObjectId('680625e5f5024b2c90d00fe6'), 'Entity': 'Asia', 'Code': nan, 'Year': 1990, 'Renewables (% equivalent primary energy)': 5.339282}
# {'_id': ObjectId('680625e5f5024b2c90d00fe7'), 'Entity': 'Asia', 'Code': nan, 'Year': 1991, 'Renewables (% equivalent primary energy)': 5.1891055}
# {'_id': ObjectId('680625e5f5024b2c90d00fe8'), 'Entity': 'Asia', 'Code': nan, 'Year': 1992, 'Renewables (% equivalent primary energy)': 5.0055637}
# {'_id': ObjectId('680625e5f5024b2c90d00fe9'), 'Entity': 'Asia', 'Code': nan, 'Year': 1993, 'Renewables (% equivalent primary energy)': 5.3127103}
# {'_id': ObjectId('680625e5f5024b2c90d00fea'), 'Entity': 'Asia', 'Code': nan, 'Year': 1994, 'Renewables (% equivalent primary energy)': 5.0516157}
# {'_id': ObjectId('680625e5f5024b2c90d00feb'), 'Entity': 'Asia', 'Code': nan, 'Year': 1995, 'Renewables (% equivalent primary energy)': 5.271553}
# {'_id': ObjectId('680625e5f5024b2c90d00fec'), 'Entity': 'Asia', 'Code': nan, 'Year': 1996, 'Renewables (% equivalent primary energy)': 5.018597}
# {'_id': ObjectId('680625e5f5024b2c90d00fed'), 'Entity': 'Asia', 'Code': nan, 'Year': 1997, 'Renewables (% equivalent primary energy)': 4.8939986}
# {'_id': ObjectId('680625e5f5024b2c90d00fee'), 'Entity': 'Asia', 'Code': nan, 'Year': 1998, 'Renewables (% equivalent primary energy)': 5.178817}
# {'_id': ObjectId('680625e5f5024b2c90d00fef'), 'Entity': 'Asia', 'Code': nan, 'Year': 1999, 'Renewables (% equivalent primary energy)': 4.9296236}
# {'_id': ObjectId('680625e5f5024b2c90d00ff0'), 'Entity': 'Asia', 'Code': nan, 'Year': 2000, 'Renewables (% equivalent primary energy)': 4.9015436}
# {'_id': ObjectId('680625e5f5024b2c90d00ff1'), 'Entity': 'Asia', 'Code': nan, 'Year': 2001, 'Renewables (% equivalent primary energy)': 5.0736527}
# {'_id': ObjectId('680625e5f5024b2c90d00ff2'), 'Entity': 'Asia', 'Code': nan, 'Year': 2002, 'Renewables (% equivalent primary energy)': 4.9854317}
# {'_id': ObjectId('680625e5f5024b2c90d00ff3'), 'Entity': 'Asia', 'Code': nan, 'Year': 2003, 'Renewables (% equivalent primary energy)': 4.7931614}
# {'_id': ObjectId('680625e5f5024b2c90d00ff4'), 'Entity': 'Asia', 'Code': nan, 'Year': 2004, 'Renewables (% equivalent primary energy)': 5.0985446}
# {'_id': ObjectId('680625e5f5024b2c90d00ff5'), 'Entity': 'Asia', 'Code': nan, 'Year': 2005, 'Renewables (% equivalent primary energy)': 4.9199796}
# {'_id': ObjectId('680625e5f5024b2c90d00ff6'), 'Entity': 'Asia', 'Code': nan, 'Year': 2006, 'Renewables (% equivalent primary energy)': 5.117429}
# {'_id': ObjectId('680625e5f5024b2c90d00ff7'), 'Entity': 'Asia', 'Code': nan, 'Year': 2007, 'Renewables (% equivalent primary energy)': 5.0853057}
# {'_id': ObjectId('680625e5f5024b2c90d00ff8'), 'Entity': 'Asia', 'Code': nan, 'Year': 2008, 'Renewables (% equivalent primary energy)': 5.605236}
# {'_id': ObjectId('680625e5f5024b2c90d00ff9'), 'Entity': 'Asia', 'Code': nan, 'Year': 2009, 'Renewables (% equivalent primary energy)': 5.458485}
# {'_id': ObjectId('680625e5f5024b2c90d00ffa'), 'Entity': 'Asia', 'Code': nan, 'Year': 2010, 'Renewables (% equivalent primary energy)': 5.9468226}
# {'_id': ObjectId('680625e5f5024b2c90d00ffb'), 'Entity': 'Asia', 'Code': nan, 'Year': 2011, 'Renewables (% equivalent primary energy)': 5.8778787}
# {'_id': ObjectId('680625e5f5024b2c90d00ffc'), 'Entity': 'Asia', 'Code': nan, 'Year': 2012, 'Renewables (% equivalent primary energy)': 6.4778247}
# {'_id': ObjectId('680625e5f5024b2c90d00ffd'), 'Entity': 'Asia', 'Code': nan, 'Year': 2013, 'Renewables (% equivalent primary energy)': 6.987413}
# {'_id': ObjectId('680625e5f5024b2c90d00ffe'), 'Entity': 'Asia', 'Code': nan, 'Year': 2014, 'Renewables (% equivalent primary energy)': 7.551866}
# {'_id': ObjectId('680625e5f5024b2c90d00fff'), 'Entity': 'Asia', 'Code': nan, 'Year': 2015, 'Renewables (% equivalent primary energy)': 7.908183}
# {'_id': ObjectId('680625e5f5024b2c90d01000'), 'Entity': 'Asia', 'Code': nan, 'Year': 2016, 'Renewables (% equivalent primary energy)': 8.438702}
# {'_id': ObjectId('680625e5f5024b2c90d01001'), 'Entity': 'Asia', 'Code': nan, 'Year': 2017, 'Renewables (% equivalent primary energy)': 8.845372}
# {'_id': ObjectId('680625e5f5024b2c90d01002'), 'Entity': 'Asia', 'Code': nan, 'Year': 2018, 'Renewables (% equivalent primary energy)': 9.349624}
# {'_id': ObjectId('680625e5f5024b2c90d01003'), 'Entity': 'Asia', 'Code': nan, 'Year': 2019, 'Renewables (% equivalent primary energy)': 10.002659}
# {'_id': ObjectId('680625e5f5024b2c90d01004'), 'Entity': 'Asia', 'Code': nan, 'Year': 2020, 'Renewables (% equivalent primary energy)': 10.741154}
# {'_id': ObjectId('680625e5f5024b2c90d01005'), 'Entity': 'Asia', 'Code': nan, 'Year': 2021, 'Renewables (% equivalent primary energy)': 11.2254095}
# {'_id': ObjectId('680625e5f5024b2c90d01006'), 'Entity': 'Asia', 'Code': nan, 'Year': 2022, 'Renewables (% equivalent primary energy)': 11.969987}
# {'_id': ObjectId('680625e5f5024b2c90d01007'), 'Entity': 'Asia', 'Code': nan, 'Year': 2023, 'Renewables (% equivalent primary energy)': 12.191386}
# {'_id': ObjectId('680625e5f5024b2c90d01008'), 'Entity': 'Asia Pacific (EI)', 'Code': nan, 'Year': 1965, 'Renewables (% equivalent primary energy)': 8.879346}
# {'_id': ObjectId('680625e5f5024b2c90d01009'), 'Entity': 'Asia Pacific (EI)', 'Code': nan, 'Year': 1966, 'Renewables (% equivalent primary energy)': 8.41833}
# {'_id': ObjectId('680625e5f5024b2c90d0100a'), 'Entity': 'Asia Pacific (EI)', 'Code': nan, 'Year': 1967, 'Renewables (% equivalent primary energy)': 7.6206317}
# {'_id': ObjectId('680625e5f5024b2c90d0100b'), 'Entity': 'Asia Pacific (EI)', 'Code': nan, 'Year': 1968, 'Renewables (% equivalent primary energy)': 7.814885}
# {'_id': ObjectId('680625e5f5024b2c90d0100c'), 'Entity': 'Asia Pacific (EI)', 'Code': nan, 'Year': 1969, 'Renewables (% equivalent primary energy)': 7.0542545}
# {'_id': ObjectId('680625e5f5024b2c90d0100d'), 'Entity': 'Asia Pacific (EI)', 'Code': nan, 'Year': 1970, 'Renewables (% equivalent primary energy)': 6.39634}
# {'_id': ObjectId('680625e5f5024b2c90d0100e'), 'Entity': 'Asia Pacific (EI)', 'Code': nan, 'Year': 1971, 'Renewables (% equivalent primary energy)': 6.486787}
# {'_id': ObjectId('680625e5f5024b2c90d0100f'), 'Entity': 'Asia Pacific (EI)', 'Code': nan, 'Year': 1972, 'Renewables (% equivalent primary energy)': 6.238836}
# {'_id': ObjectId('680625e5f5024b2c90d01010'), 'Entity': 'Asia Pacific (EI)', 'Code': nan, 'Year': 1973, 'Renewables (% equivalent primary energy)': 5.4947343}
# {'_id': ObjectId('680625e5f5024b2c90d01011'), 'Entity': 'Asia Pacific (EI)', 'Code': nan, 'Year': 1974, 'Renewables (% equivalent primary energy)': 6.09481}
# {'_id': ObjectId('680625e5f5024b2c90d01012'), 'Entity': 'Asia Pacific (EI)', 'Code': nan, 'Year': 1975, 'Renewables (% equivalent primary energy)': 6.1902494}
# {'_id': ObjectId('680625e5f5024b2c90d01013'), 'Entity': 'Asia Pacific (EI)', 'Code': nan, 'Year': 1976, 'Renewables (% equivalent primary energy)': 5.912254}
# {'_id': ObjectId('680625e5f5024b2c90d01014'), 'Entity': 'Asia Pacific (EI)', 'Code': nan, 'Year': 1977, 'Renewables (% equivalent primary energy)': 5.47068}
# {'_id': ObjectId('680625e5f5024b2c90d01015'), 'Entity': 'Asia Pacific (EI)', 'Code': nan, 'Year': 1978, 'Renewables (% equivalent primary energy)': 5.3867373}
# {'_id': ObjectId('680625e5f5024b2c90d01016'), 'Entity': 'Asia Pacific (EI)', 'Code': nan, 'Year': 1979, 'Renewables (% equivalent primary energy)': 5.630934}
# {'_id': ObjectId('680625e5f5024b2c90d01017'), 'Entity': 'Asia Pacific (EI)', 'Code': nan, 'Year': 1980, 'Renewables (% equivalent primary energy)': 5.9968095}
# {'_id': ObjectId('680625e5f5024b2c90d01018'), 'Entity': 'Asia Pacific (EI)', 'Code': nan, 'Year': 1981, 'Renewables (% equivalent primary energy)': 6.3445344}
# {'_id': ObjectId('680625e5f5024b2c90d01019'), 'Entity': 'Asia Pacific (EI)', 'Code': nan, 'Year': 1982, 'Renewables (% equivalent primary energy)': 6.3195252}
# {'_id': ObjectId('680625e5f5024b2c90d0101a'), 'Entity': 'Asia Pacific (EI)', 'Code': nan, 'Year': 1983, 'Renewables (% equivalent primary energy)': 6.4025097}
# {'_id': ObjectId('680625e5f5024b2c90d0101b'), 'Entity': 'Asia Pacific (EI)', 'Code': nan, 'Year': 1984, 'Renewables (% equivalent primary energy)': 6.0936494}
# {'_id': ObjectId('680625e5f5024b2c90d0101c'), 'Entity': 'Asia Pacific (EI)', 'Code': nan, 'Year': 1985, 'Renewables (% equivalent primary energy)': 6.1765556}
# {'_id': ObjectId('680625e5f5024b2c90d0101d'), 'Entity': 'Asia Pacific (EI)', 'Code': nan, 'Year': 1986, 'Renewables (% equivalent primary energy)': 6.0954514}
# {'_id': ObjectId('680625e5f5024b2c90d0101e'), 'Entity': 'Asia Pacific (EI)', 'Code': nan, 'Year': 1987, 'Renewables (% equivalent primary energy)': 5.7225227}
# ...
# {'_id': ObjectId('680625e5f5024b2c90d021a2'), 'Entity': 'Western Africa (EI)', 'Code': nan, 'Year': 1981, 'Renewables (% equivalent primary energy)': 12.494397}
# {'_id': ObjectId('680625e5f5024b2c90d021a3'), 'Entity': 'Western Africa (EI)', 'Code': nan, 'Year': 1982, 'Renewables (% equivalent primary energy)': 11.68581}
# {'_id': ObjectId('680625e5f5024b2c90d021a4'), 'Entity': 'Western Africa (EI)', 'Code': nan, 'Year': 1983, 'Renewables (% equivalent primary energy)': 7.7634754}
# {'_id': ObjectId('680625e5f5024b2c90d021a5'), 'Entity': 'Western Africa (EI)', 'Code': nan, 'Year': 1984, 'Renewables (% equivalent primary energy)': 7.5681634}
# {'_id': ObjectId('680625e5f5024b2c90d021a6'), 'Entity': 'Western Africa (EI)', 'Code': nan, 'Year': 1985, 'Renewables (% equivalent primary energy)': 11.242959}
# {'_id': ObjectId('680625e5f5024b2c90d021a7'), 'Entity': 'Western Africa (EI)', 'Code': nan, 'Year': 1986, 'Renewables (% equivalent primary energy)': 13.811244}
# {'_id': ObjectId('680625e5f5024b2c90d021a8'), 'Entity': 'Western Africa (EI)', 'Code': nan, 'Year': 1987, 'Renewables (% equivalent primary energy)': 12.9425125}
# {'_id': ObjectId('680625e5f5024b2c90d021a9'), 'Entity': 'Western Africa (EI)', 'Code': nan, 'Year': 1988, 'Renewables (% equivalent primary energy)': 13.430492}
# {'_id': ObjectId('680625e5f5024b2c90d021aa'), 'Entity': 'Western Africa (EI)', 'Code': nan, 'Year': 1989, 'Renewables (% equivalent primary energy)': 13.813509}
# {'_id': ObjectId('680625e5f5024b2c90d021ab'), 'Entity': 'Western Africa (EI)', 'Code': nan, 'Year': 1990, 'Renewables (% equivalent primary energy)': 14.452316}
# {'_id': ObjectId('680625e5f5024b2c90d021ac'), 'Entity': 'Western Africa (EI)', 'Code': nan, 'Year': 1991, 'Renewables (% equivalent primary energy)': 15.77723}
# {'_id': ObjectId('680625e5f5024b2c90d021ad'), 'Entity': 'Western Africa (EI)', 'Code': nan, 'Year': 1992, 'Renewables (% equivalent primary energy)': 15.0170355}
# {'_id': ObjectId('680625e5f5024b2c90d021ae'), 'Entity': 'Western Africa (EI)', 'Code': nan, 'Year': 1993, 'Renewables (% equivalent primary energy)': 14.30466}
# {'_id': ObjectId('680625e5f5024b2c90d021af'), 'Entity': 'Western Africa (EI)', 'Code': nan, 'Year': 1994, 'Renewables (% equivalent primary energy)': 14.307501}
# {'_id': ObjectId('680625e5f5024b2c90d021b0'), 'Entity': 'Western Africa (EI)', 'Code': nan, 'Year': 1995, 'Renewables (% equivalent primary energy)': 14.58253}
# {'_id': ObjectId('680625e5f5024b2c90d021b1'), 'Entity': 'Western Africa (EI)', 'Code': nan, 'Year': 1996, 'Renewables (% equivalent primary energy)': 13.991099}
# {'_id': ObjectId('680625e5f5024b2c90d021b2'), 'Entity': 'Western Africa (EI)', 'Code': nan, 'Year': 1997, 'Renewables (% equivalent primary energy)': 14.335823}
# {'_id': ObjectId('680625e5f5024b2c90d021b3'), 'Entity': 'Western Africa (EI)', 'Code': nan, 'Year': 1998, 'Renewables (% equivalent primary energy)': 11.193091}
# {'_id': ObjectId('680625e5f5024b2c90d021b4'), 'Entity': 'Western Africa (EI)', 'Code': nan, 'Year': 1999, 'Renewables (% equivalent primary energy)': 13.094856}
# {'_id': ObjectId('680625e5f5024b2c90d021b5'), 'Entity': 'Western Africa (EI)', 'Code': nan, 'Year': 2000, 'Renewables (% equivalent primary energy)': 13.095548}
# {'_id': ObjectId('680625e5f5024b2c90d021b6'), 'Entity': 'Western Africa (EI)', 'Code': nan, 'Year': 2001, 'Renewables (% equivalent primary energy)': 12.301518}
# {'_id': ObjectId('680625e5f5024b2c90d021b7'), 'Entity': 'Western Africa (EI)', 'Code': nan, 'Year': 2002, 'Renewables (% equivalent primary energy)': 11.809273}
# {'_id': ObjectId('680625e5f5024b2c90d021b8'), 'Entity': 'Western Africa (EI)', 'Code': nan, 'Year': 2003, 'Renewables (% equivalent primary energy)': 10.583202}
# {'_id': ObjectId('680625e5f5024b2c90d021b9'), 'Entity': 'Western Africa (EI)', 'Code': nan, 'Year': 2004, 'Renewables (% equivalent primary energy)': 11.762157}
# {'_id': ObjectId('680625e5f5024b2c90d021ba'), 'Entity': 'Western Africa (EI)', 'Code': nan, 'Year': 2005, 'Renewables (% equivalent primary energy)': 11.003373}
# {'_id': ObjectId('680625e5f5024b2c90d021bb'), 'Entity': 'Western Africa (EI)', 'Code': nan, 'Year': 2006, 'Renewables (% equivalent primary energy)': 10.950638}
# {'_id': ObjectId('680625e5f5024b2c90d021bc'), 'Entity': 'Western Africa (EI)', 'Code': nan, 'Year': 2007, 'Renewables (% equivalent primary energy)': 9.16278}
# {'_id': ObjectId('680625e5f5024b2c90d021bd'), 'Entity': 'Western Africa (EI)', 'Code': nan, 'Year': 2008, 'Renewables (% equivalent primary energy)': 9.841228}
# {'_id': ObjectId('680625e5f5024b2c90d021be'), 'Entity': 'Western Africa (EI)', 'Code': nan, 'Year': 2009, 'Renewables (% equivalent primary energy)': 10.236668}
# {'_id': ObjectId('680625e5f5024b2c90d021bf'), 'Entity': 'Western Africa (EI)', 'Code': nan, 'Year': 2010, 'Renewables (% equivalent primary energy)': 10.912234}
# {'_id': ObjectId('680625e5f5024b2c90d021c0'), 'Entity': 'Western Africa (EI)', 'Code': nan, 'Year': 2011, 'Renewables (% equivalent primary energy)': 10.084756}
# {'_id': ObjectId('680625e5f5024b2c90d021c1'), 'Entity': 'Western Africa (EI)', 'Code': nan, 'Year': 2012, 'Renewables (% equivalent primary energy)': 9.786942}
# {'_id': ObjectId('680625e5f5024b2c90d021c2'), 'Entity': 'Western Africa (EI)', 'Code': nan, 'Year': 2013, 'Renewables (% equivalent primary energy)': 9.337499}
# {'_id': ObjectId('680625e5f5024b2c90d021c3'), 'Entity': 'Western Africa (EI)', 'Code': nan, 'Year': 2014, 'Renewables (% equivalent primary energy)': 9.446895}
# {'_id': ObjectId('680625e5f5024b2c90d021c4'), 'Entity': 'Western Africa (EI)', 'Code': nan, 'Year': 2015, 'Renewables (% equivalent primary energy)': 7.3576255}
# {'_id': ObjectId('680625e5f5024b2c90d021c5'), 'Entity': 'Western Africa (EI)', 'Code': nan, 'Year': 2016, 'Renewables (% equivalent primary energy)': 8.244503}
# {'_id': ObjectId('680625e5f5024b2c90d021c6'), 'Entity': 'Western Africa (EI)', 'Code': nan, 'Year': 2017, 'Renewables (% equivalent primary energy)': 7.833715}
# {'_id': ObjectId('680625e5f5024b2c90d021c7'), 'Entity': 'Western Africa (EI)', 'Code': nan, 'Year': 2018, 'Renewables (% equivalent primary energy)': 7.440964}
# {'_id': ObjectId('680625e5f5024b2c90d021c8'), 'Entity': 'Western Africa (EI)', 'Code': nan, 'Year': 2019, 'Renewables (% equivalent primary energy)': 8.164477}
# {'_id': ObjectId('680625e5f5024b2c90d021c9'), 'Entity': 'Western Africa (EI)', 'Code': nan, 'Year': 2020, 'Renewables (% equivalent primary energy)': 8.095408}
# {'_id': ObjectId('680625e5f5024b2c90d021ca'), 'Entity': 'Western Africa (EI)', 'Code': nan, 'Year': 2021, 'Renewables (% equivalent primary energy)': 7.4288955}
# {'_id': ObjectId('680625e5f5024b2c90d021cb'), 'Entity': 'Western Africa (EI)', 'Code': nan, 'Year': 2022, 'Renewables (% equivalent primary energy)': 7.8159766}
# {'_id': ObjectId('680625e5f5024b2c90d021cc'), 'Entity': 'Western Africa (EI)', 'Code': nan, 'Year': 2023, 'Renewables (% equivalent primary energy)': 8.792076}
# {'_id': ObjectId('680625e5f5024b2c90d021cd'), 'Entity': 'World', 'Code': 'OWID_WRL', 'Year': 1965, 'Renewables (% equivalent primary energy)': 6.445519}
# {'_id': ObjectId('680625e5f5024b2c90d021ce'), 'Entity': 'World', 'Code': 'OWID_WRL', 'Year': 1966, 'Renewables (% equivalent primary energy)': 6.516204}
# {'_id': ObjectId('680625e5f5024b2c90d021cf'), 'Entity': 'World', 'Code': 'OWID_WRL', 'Year': 1967, 'Renewables (% equivalent primary energy)': 6.423987}
# {'_id': ObjectId('680625e5f5024b2c90d021d0'), 'Entity': 'World', 'Code': 'OWID_WRL', 'Year': 1968, 'Renewables (% equivalent primary energy)': 6.3901453}
# {'_id': ObjectId('680625e5f5024b2c90d021d1'), 'Entity': 'World', 'Code': 'OWID_WRL', 'Year': 1969, 'Renewables (% equivalent primary energy)': 6.32996}
# {'_id': ObjectId('680625e5f5024b2c90d021d2'), 'Entity': 'World', 'Code': 'OWID_WRL', 'Year': 1970, 'Renewables (% equivalent primary energy)': 6.2402315}
# {'_id': ObjectId('680625e5f5024b2c90d021d3'), 'Entity': 'World', 'Code': 'OWID_WRL', 'Year': 1971, 'Renewables (% equivalent primary energy)': 6.2751184}
# {'_id': ObjectId('680625e5f5024b2c90d021d4'), 'Entity': 'World', 'Code': 'OWID_WRL', 'Year': 1972, 'Renewables (% equivalent primary energy)': 6.231038}
# {'_id': ObjectId('680625e5f5024b2c90d021d5'), 'Entity': 'World', 'Code': 'OWID_WRL', 'Year': 1973, 'Renewables (% equivalent primary energy)': 5.98148}
# {'_id': ObjectId('680625e5f5024b2c90d021d6'), 'Entity': 'World', 'Code': 'OWID_WRL', 'Year': 1974, 'Renewables (% equivalent primary energy)': 6.527657}
# {'_id': ObjectId('680625e5f5024b2c90d021d7'), 'Entity': 'World', 'Code': 'OWID_WRL', 'Year': 1975, 'Renewables (% equivalent primary energy)': 6.5613737}
# {'_id': ObjectId('680625e5f5024b2c90d021d8'), 'Entity': 'World', 'Code': 'OWID_WRL', 'Year': 1976, 'Renewables (% equivalent primary energy)': 6.2220235}
# {'_id': ObjectId('680625e5f5024b2c90d021d9'), 'Entity': 'World', 'Code': 'OWID_WRL', 'Year': 1977, 'Renewables (% equivalent primary energy)': 6.216026}
# {'_id': ObjectId('680625e5f5024b2c90d021da'), 'Entity': 'World', 'Code': 'OWID_WRL', 'Year': 1978, 'Renewables (% equivalent primary energy)': 6.4746337}
# {'_id': ObjectId('680625e5f5024b2c90d021db'), 'Entity': 'World', 'Code': 'OWID_WRL', 'Year': 1979, 'Renewables (% equivalent primary energy)': 6.5883255}
# {'_id': ObjectId('680625e5f5024b2c90d021dc'), 'Entity': 'World', 'Code': 'OWID_WRL', 'Year': 1980, 'Renewables (% equivalent primary energy)': 6.8036585}
# {'_id': ObjectId('680625e5f5024b2c90d021dd'), 'Entity': 'World', 'Code': 'OWID_WRL', 'Year': 1981, 'Renewables (% equivalent primary energy)': 6.9859357}
# {'_id': ObjectId('680625e5f5024b2c90d021de'), 'Entity': 'World', 'Code': 'OWID_WRL', 'Year': 1982, 'Renewables (% equivalent primary energy)': 7.1871624}
# {'_id': ObjectId('680625e5f5024b2c90d021df'), 'Entity': 'World', 'Code': 'OWID_WRL', 'Year': 1983, 'Renewables (% equivalent primary energy)': 7.3960943}
# {'_id': ObjectId('680625e5f5024b2c90d021e0'), 'Entity': 'World', 'Code': 'OWID_WRL', 'Year': 1984, 'Renewables (% equivalent primary energy)': 7.3479614}
# {'_id': ObjectId('680625e5f5024b2c90d021e1'), 'Entity': 'World', 'Code': 'OWID_WRL', 'Year': 1985, 'Renewables (% equivalent primary energy)': 7.309479}
# {'_id': ObjectId('680625e5f5024b2c90d021e2'), 'Entity': 'World', 'Code': 'OWID_WRL', 'Year': 1986, 'Renewables (% equivalent primary energy)': 7.2850266}
# {'_id': ObjectId('680625e5f5024b2c90d021e3'), 'Entity': 'World', 'Code': 'OWID_WRL', 'Year': 1987, 'Renewables (% equivalent primary energy)': 7.1429477}
# {'_id': ObjectId('680625e5f5024b2c90d021e4'), 'Entity': 'World', 'Code': 'OWID_WRL', 'Year': 1988, 'Renewables (% equivalent primary energy)': 7.10847}
# {'_id': ObjectId('680625e5f5024b2c90d021e5'), 'Entity': 'World', 'Code': 'OWID_WRL', 'Year': 1989, 'Renewables (% equivalent primary energy)': 6.9876184}
# {'_id': ObjectId('680625e5f5024b2c90d021e6'), 'Entity': 'World', 'Code': 'OWID_WRL', 'Year': 1990, 'Renewables (% equivalent primary energy)': 7.182692}
# {'_id': ObjectId('680625e5f5024b2c90d021e7'), 'Entity': 'World', 'Code': 'OWID_WRL', 'Year': 1991, 'Renewables (% equivalent primary energy)': 7.301195}
# {'_id': ObjectId('680625e5f5024b2c90d021e8'), 'Entity': 'World', 'Code': 'OWID_WRL', 'Year': 1992, 'Renewables (% equivalent primary energy)': 7.2864876}
# {'_id': ObjectId('680625e5f5024b2c90d021e9'), 'Entity': 'World', 'Code': 'OWID_WRL', 'Year': 1993, 'Renewables (% equivalent primary energy)': 7.6539183}
# {'_id': ObjectId('680625e5f5024b2c90d021ea'), 'Entity': 'World', 'Code': 'OWID_WRL', 'Year': 1994, 'Renewables (% equivalent primary energy)': 7.6321683}
# {'_id': ObjectId('680625e5f5024b2c90d021eb'), 'Entity': 'World', 'Code': 'OWID_WRL', 'Year': 1995, 'Renewables (% equivalent primary energy)': 7.8718243}
# {'_id': ObjectId('680625e5f5024b2c90d021ec'), 'Entity': 'World', 'Code': 'OWID_WRL', 'Year': 1996, 'Renewables (% equivalent primary energy)': 7.755703}
# {'_id': ObjectId('680625e5f5024b2c90d021ed'), 'Entity': 'World', 'Code': 'OWID_WRL', 'Year': 1997, 'Renewables (% equivalent primary energy)': 7.847491}
# {'_id': ObjectId('680625e5f5024b2c90d021ee'), 'Entity': 'World', 'Code': 'OWID_WRL', 'Year': 1998, 'Renewables (% equivalent primary energy)': 7.890869}
# {'_id': ObjectId('680625e5f5024b2c90d021ef'), 'Entity': 'World', 'Code': 'OWID_WRL', 'Year': 1999, 'Renewables (% equivalent primary energy)': 7.8530593}
# {'_id': ObjectId('680625e5f5024b2c90d021f0'), 'Entity': 'World', 'Code': 'OWID_WRL', 'Year': 2000, 'Renewables (% equivalent primary energy)': 7.8158455}
# {'_id': ObjectId('680625e5f5024b2c90d021f1'), 'Entity': 'World', 'Code': 'OWID_WRL', 'Year': 2001, 'Renewables (% equivalent primary energy)': 7.552836}
# {'_id': ObjectId('680625e5f5024b2c90d021f2'), 'Entity': 'World', 'Code': 'OWID_WRL', 'Year': 2002, 'Renewables (% equivalent primary energy)': 7.5668545}
# {'_id': ObjectId('680625e5f5024b2c90d021f3'), 'Entity': 'World', 'Code': 'OWID_WRL', 'Year': 2003, 'Renewables (% equivalent primary energy)': 7.3342075}
# {'_id': ObjectId('680625e5f5024b2c90d021f4'), 'Entity': 'World', 'Code': 'OWID_WRL', 'Year': 2004, 'Renewables (% equivalent primary energy)': 7.518}
# {'_id': ObjectId('680625e5f5024b2c90d021f5'), 'Entity': 'World', 'Code': 'OWID_WRL', 'Year': 2005, 'Renewables (% equivalent primary energy)': 7.5638204}
# {'_id': ObjectId('680625e5f5024b2c90d021f6'), 'Entity': 'World', 'Code': 'OWID_WRL', 'Year': 2006, 'Renewables (% equivalent primary energy)': 7.705343}
# {'_id': ObjectId('680625e5f5024b2c90d021f7'), 'Entity': 'World', 'Code': 'OWID_WRL', 'Year': 2007, 'Renewables (% equivalent primary energy)': 7.7473364}
# {'_id': ObjectId('680625e5f5024b2c90d021f8'), 'Entity': 'World', 'Code': 'OWID_WRL', 'Year': 2008, 'Renewables (% equivalent primary energy)': 8.245706}
# {'_id': ObjectId('680625e5f5024b2c90d021f9'), 'Entity': 'World', 'Code': 'OWID_WRL', 'Year': 2009, 'Renewables (% equivalent primary energy)': 8.564856}
# {'_id': ObjectId('680625e5f5024b2c90d021fa'), 'Entity': 'World', 'Code': 'OWID_WRL', 'Year': 2010, 'Renewables (% equivalent primary energy)': 8.797048}
# {'_id': ObjectId('680625e5f5024b2c90d021fb'), 'Entity': 'World', 'Code': 'OWID_WRL', 'Year': 2011, 'Renewables (% equivalent primary energy)': 8.980997}
# {'_id': ObjectId('680625e5f5024b2c90d021fc'), 'Entity': 'World', 'Code': 'OWID_WRL', 'Year': 2012, 'Renewables (% equivalent primary energy)': 9.414955}
# {'_id': ObjectId('680625e5f5024b2c90d021fd'), 'Entity': 'World', 'Code': 'OWID_WRL', 'Year': 2013, 'Renewables (% equivalent primary energy)': 9.847355}
# {'_id': ObjectId('680625e5f5024b2c90d021fe'), 'Entity': 'World', 'Code': 'OWID_WRL', 'Year': 2014, 'Renewables (% equivalent primary energy)': 10.218171}
# {'_id': ObjectId('680625e5f5024b2c90d021ff'), 'Entity': 'World', 'Code': 'OWID_WRL', 'Year': 2015, 'Renewables (% equivalent primary energy)': 10.504495}
# {'_id': ObjectId('680625e5f5024b2c90d02200'), 'Entity': 'World', 'Code': 'OWID_WRL', 'Year': 2016, 'Renewables (% equivalent primary energy)': 10.980251}
# {'_id': ObjectId('680625e5f5024b2c90d02201'), 'Entity': 'World', 'Code': 'OWID_WRL', 'Year': 2017, 'Renewables (% equivalent primary energy)': 11.337292}
# {'_id': ObjectId('680625e5f5024b2c90d02202'), 'Entity': 'World', 'Code': 'OWID_WRL', 'Year': 2018, 'Renewables (% equivalent primary energy)': 11.743186}
# {'_id': ObjectId('680625e5f5024b2c90d02203'), 'Entity': 'World', 'Code': 'OWID_WRL', 'Year': 2019, 'Renewables (% equivalent primary energy)': 12.228147}
# {'_id': ObjectId('680625e5f5024b2c90d02204'), 'Entity': 'World', 'Code': 'OWID_WRL', 'Year': 2020, 'Renewables (% equivalent primary energy)': 13.404395}
# {'_id': ObjectId('680625e5f5024b2c90d02205'), 'Entity': 'World', 'Code': 'OWID_WRL', 'Year': 2021, 'Renewables (% equivalent primary energy)': 13.469198}
# {'_id': ObjectId('680625e5f5024b2c90d02206'), 'Entity': 'World', 'Code': 'OWID_WRL', 'Year': 2022, 'Renewables (% equivalent primary energy)': 14.119935}
# {'_id': ObjectId('680625e5f5024b2c90d02207'), 'Entity': 'World', 'Code': 'OWID_WRL', 'Year': 2023, 'Renewables (% equivalent primary energy)': 14.562141}

# %%
renewable_all_records = renewable_collection.find()

# %%
print(renewable_all_records)
# Out:
# <pymongo.synchronous.cursor.Cursor object at 0x0000025CE381E350>

# %%
renewable_list_cursor=list(renewable_all_records)

# %%
renewable_list_cursor
# Out:
# [{'_id': ObjectId('680625e5f5024b2c90d00ee1'),
#   'Entity': 'Africa',
#   'Code': nan,
#   'Year': 1965,
#   'Renewables (% equivalent primary energy)': 5.7402806},
#  {'_id': ObjectId('680625e5f5024b2c90d00ee2'),
#   'Entity': 'Africa',
#   'Code': nan,
#   'Year': 1966,
#   'Renewables (% equivalent primary energy)': 6.1139693},
#  {'_id': ObjectId('680625e5f5024b2c90d00ee3'),
#   'Entity': 'Africa',
#   'Code': nan,
#   'Year': 1967,
#   'Renewables (% equivalent primary energy)': 6.31658},
#  {'_id': ObjectId('680625e5f5024b2c90d00ee4'),
#   'Entity': 'Africa',
#   'Code': nan,
#   'Year': 1968,
#   'Renewables (% equivalent primary energy)': 6.994845},
#  {'_id': ObjectId('680625e5f5024b2c90d00ee5'),
#   'Entity': 'Africa',
#   'Code': nan,
#   'Year': 1969,
#   'Renewables (% equivalent primary energy)': 7.9439163},
#  {'_id': ObjectId('680625e5f5024b2c90d00ee6'),
#   'Entity': 'Africa',
#   'Code': nan,
#   'Year': 1970,
#   'Renewables (% equivalent primary energy)': 9.148895},
#  {'_id': ObjectId('680625e5f5024b2c90d00ee7'),
#   'Entity': 'Africa',
#   'Code': nan,
#   'Year': 1971,
#   'Renewables (% equivalent primary energy)': 8.124994},
#  {'_id': ObjectId('680625e5f5024b2c90d00ee8'),
#   'Entity': 'Africa',
#   'Code': nan,
#   'Year': 1972,
#   'Renewables (% equivalent primary energy)': 8.747272},
#  {'_id': ObjectId('680625e5f5024b2c90d00ee9'),
#   'Entity': 'Africa',
#   'Code': nan,
#   'Year': 1973,
#   'Renewables (% equivalent primary energy)': 8.54162},
#  {'_id': ObjectId('680625e5f5024b2c90d00eea'),
#   'Entity': 'Africa',
#   'Code': nan,
#   'Year': 1974,
#   'Renewables (% equivalent primary energy)': 9.252387},
#  {'_id': ObjectId('680625e5f5024b2c90d00eeb'),
#   'Entity': 'Africa',
#   'Code': nan,
#   'Year': 1975,
#   'Renewables (% equivalent primary energy)': 9.228769},
#  {'_id': ObjectId('680625e5f5024b2c90d00eec'),
#   'Entity': 'Africa',
#   'Code': nan,
#   'Year': 1976,
#   'Renewables (% equivalent primary energy)': 9.41638},
#  {'_id': ObjectId('680625e5f5024b2c90d00eed'),
#   'Entity': 'Africa',
#   'Code': nan,
#   'Year': 1977,
#   'Renewables (% equivalent primary energy)': 9.803094},
#  {'_id': ObjectId('680625e5f5024b2c90d00eee'),
#   'Entity': 'Africa',
#   'Code': nan,
#   'Year': 1978,
#   'Renewables (% equivalent primary energy)': 9.518462},
#  {'_id': ObjectId('680625e5f5024b2c90d00eef'),
#   'Entity': 'Africa',
#   'Code': nan,
#   'Year': 1979,
#   'Renewables (% equivalent primary energy)': 9.349527},
#  {'_id': ObjectId('680625e5f5024b2c90d00ef0'),
#   'Entity': 'Africa',
#   'Code': nan,
#   'Year': 1980,
#   'Renewables (% equivalent primary energy)': 8.481442},
#  {'_id': ObjectId('680625e5f5024b2c90d00ef1'),
#   'Entity': 'Africa',
#   'Code': nan,
#   'Year': 1981,
#   'Renewables (% equivalent primary energy)': 7.8527517},
#  {'_id': ObjectId('680625e5f5024b2c90d00ef2'),
#   'Entity': 'Africa',
#   'Code': nan,
#   'Year': 1982,
#   'Renewables (% equivalent primary energy)': 7.3734274},
#  {'_id': ObjectId('680625e5f5024b2c90d00ef3'),
#   'Entity': 'Africa',
#   'Code': nan,
#   'Year': 1983,
#   'Renewables (% equivalent primary energy)': 6.456112},
#  {'_id': ObjectId('680625e5f5024b2c90d00ef4'),
#   'Entity': 'Africa',
#   'Code': nan,
#   'Year': 1984,
#   'Renewables (% equivalent primary energy)': 6.1585774},
#  {'_id': ObjectId('680625e5f5024b2c90d00ef5'),
#   'Entity': 'Africa',
#   'Code': nan,
#   'Year': 1985,
#   'Renewables (% equivalent primary energy)': 6.5793424},
#  {'_id': ObjectId('680625e5f5024b2c90d00ef6'),
#   'Entity': 'Africa',
#   'Code': nan,
#   'Year': 1986,
#   'Renewables (% equivalent primary energy)': 6.7159667},
#  {'_id': ObjectId('680625e5f5024b2c90d00ef7'),
#   'Entity': 'Africa',
#   'Code': nan,
#   'Year': 1987,
#   'Renewables (% equivalent primary energy)': 6.243963},
#  {'_id': ObjectId('680625e5f5024b2c90d00ef8'),
#   'Entity': 'Africa',
#   'Code': nan,
#   'Year': 1988,
#   'Renewables (% equivalent primary energy)': 6.3621163},
#  {'_id': ObjectId('680625e5f5024b2c90d00ef9'),
#   'Entity': 'Africa',
#   'Code': nan,
#   'Year': 1989,
#   'Renewables (% equivalent primary energy)': 6.66546},
#  {'_id': ObjectId('680625e5f5024b2c90d00efa'),
#   'Entity': 'Africa',
#   'Code': nan,
#   'Year': 1990,
#   'Renewables (% equivalent primary energy)': 6.5857716},
#  {'_id': ObjectId('680625e5f5024b2c90d00efb'),
#   'Entity': 'Africa',
#   'Code': nan,
#   'Year': 1991,
#   'Renewables (% equivalent primary energy)': 6.9810143},
#  {'_id': ObjectId('680625e5f5024b2c90d00efc'),
#   'Entity': 'Africa',
#   'Code': nan,
#   'Year': 1992,
#   'Renewables (% equivalent primary energy)': 6.5694675},
#  {'_id': ObjectId('680625e5f5024b2c90d00efd'),
#   'Entity': 'Africa',
#   'Code': nan,
#   'Year': 1993,
#   'Renewables (% equivalent primary energy)': 6.43179},
#  {'_id': ObjectId('680625e5f5024b2c90d00efe'),
#   'Entity': 'Africa',
#   'Code': nan,
#   'Year': 1994,
#   'Renewables (% equivalent primary energy)': 6.3092456},
#  {'_id': ObjectId('680625e5f5024b2c90d00eff'),
#   'Entity': 'Africa',
#   'Code': nan,
#   'Year': 1995,
#   'Renewables (% equivalent primary energy)': 6.306244},
#  {'_id': ObjectId('680625e5f5024b2c90d00f00'),
#   'Entity': 'Africa',
#   'Code': nan,
#   'Year': 1996,
#   'Renewables (% equivalent primary energy)': 6.4332542},
#  {'_id': ObjectId('680625e5f5024b2c90d00f01'),
#   'Entity': 'Africa',
#   'Code': nan,
#   'Year': 1997,
#   'Renewables (% equivalent primary energy)': 6.465725},
#  {'_id': ObjectId('680625e5f5024b2c90d00f02'),
#   'Entity': 'Africa',
#   'Code': nan,
#   'Year': 1998,
#   'Renewables (% equivalent primary energy)': 6.676159},
#  {'_id': ObjectId('680625e5f5024b2c90d00f03'),
#   'Entity': 'Africa',
#   'Code': nan,
#   'Year': 1999,
#   'Renewables (% equivalent primary energy)': 6.858631},
#  {'_id': ObjectId('680625e5f5024b2c90d00f04'),
#   'Entity': 'Africa',
#   'Code': nan,
#   'Year': 2000,
#   'Renewables (% equivalent primary energy)': 7.2029395},
#  {'_id': ObjectId('680625e5f5024b2c90d00f05'),
#   'Entity': 'Africa',
#   'Code': nan,
#   'Year': 2001,
#   'Renewables (% equivalent primary energy)': 7.4362373},
#  {'_id': ObjectId('680625e5f5024b2c90d00f06'),
#   'Entity': 'Africa',
#   'Code': nan,
#   'Year': 2002,
#   'Renewables (% equivalent primary energy)': 7.671944},
#  {'_id': ObjectId('680625e5f5024b2c90d00f07'),
#   'Entity': 'Africa',
#   'Code': nan,
#   'Year': 2003,
#   'Renewables (% equivalent primary energy)': 7.105203},
#  {'_id': ObjectId('680625e5f5024b2c90d00f08'),
#   'Entity': 'Africa',
#   'Code': nan,
#   'Year': 2004,
#   'Renewables (% equivalent primary energy)': 6.980063},
#  {'_id': ObjectId('680625e5f5024b2c90d00f09'),
#   'Entity': 'Africa',
#   'Code': nan,
#   'Year': 2005,
#   'Renewables (% equivalent primary energy)': 7.0285006},
#  {'_id': ObjectId('680625e5f5024b2c90d00f0a'),
#   'Entity': 'Africa',
#   'Code': nan,
#   'Year': 2006,
#   'Renewables (% equivalent primary energy)': 7.1611776},
#  {'_id': ObjectId('680625e5f5024b2c90d00f0b'),
#   'Entity': 'Africa',
#   'Code': nan,
#   'Year': 2007,
#   'Renewables (% equivalent primary energy)': 7.0572457},
#  {'_id': ObjectId('680625e5f5024b2c90d00f0c'),
#   'Entity': 'Africa',
#   'Code': nan,
#   'Year': 2008,
#   'Renewables (% equivalent primary energy)': 6.761787},
#  {'_id': ObjectId('680625e5f5024b2c90d00f0d'),
#   'Entity': 'Africa',
#   'Code': nan,
#   'Year': 2009,
#   'Renewables (% equivalent primary energy)': 6.810709},
#  {'_id': ObjectId('680625e5f5024b2c90d00f0e'),
#   'Entity': 'Africa',
#   'Code': nan,
#   'Year': 2010,
#   'Renewables (% equivalent primary energy)': 7.1290402},
#  {'_id': ObjectId('680625e5f5024b2c90d00f0f'),
#   'Entity': 'Africa',
#   'Code': nan,
#   'Year': 2011,
#   'Renewables (% equivalent primary energy)': 7.2594023},
#  {'_id': ObjectId('680625e5f5024b2c90d00f10'),
#   'Entity': 'Africa',
#   'Code': nan,
#   'Year': 2012,
#   'Renewables (% equivalent primary energy)': 6.9972486},
#  {'_id': ObjectId('680625e5f5024b2c90d00f11'),
#   'Entity': 'Africa',
#   'Code': nan,
#   'Year': 2013,
#   'Renewables (% equivalent primary energy)': 7.189637},
#  {'_id': ObjectId('680625e5f5024b2c90d00f12'),
#   'Entity': 'Africa',
#   'Code': nan,
#   'Year': 2014,
#   'Renewables (% equivalent primary energy)': 7.5156765},
#  {'_id': ObjectId('680625e5f5024b2c90d00f13'),
#   'Entity': 'Africa',
#   'Code': nan,
#   'Year': 2015,
#   'Renewables (% equivalent primary energy)': 7.527505},
#  {'_id': ObjectId('680625e5f5024b2c90d00f14'),
#   'Entity': 'Africa',
#   'Code': nan,
#   'Year': 2016,
#   'Renewables (% equivalent primary energy)': 7.404274},
#  {'_id': ObjectId('680625e5f5024b2c90d00f15'),
#   'Entity': 'Africa',
#   'Code': nan,
#   'Year': 2017,
#   'Renewables (% equivalent primary energy)': 7.6419463},
#  {'_id': ObjectId('680625e5f5024b2c90d00f16'),
#   'Entity': 'Africa',
#   'Code': nan,
#   'Year': 2018,
#   'Renewables (% equivalent primary energy)': 8.005552},
#  {'_id': ObjectId('680625e5f5024b2c90d00f17'),
#   'Entity': 'Africa',
#   'Code': nan,
#   'Year': 2019,
#   'Renewables (% equivalent primary energy)': 8.356321},
#  {'_id': ObjectId('680625e5f5024b2c90d00f18'),
#   'Entity': 'Africa',
#   'Code': nan,
#   'Year': 2020,
#   'Renewables (% equivalent primary energy)': 9.415897},
#  {'_id': ObjectId('680625e5f5024b2c90d00f19'),
#   'Entity': 'Africa',
#   'Code': nan,
#   'Year': 2021,
#   'Renewables (% equivalent primary energy)': 9.152215},
#  {'_id': ObjectId('680625e5f5024b2c90d00f1a'),
#   'Entity': 'Africa',
#   'Code': nan,
#   'Year': 2022,
#   'Renewables (% equivalent primary energy)': 9.298186},
#  {'_id': ObjectId('680625e5f5024b2c90d00f1b'),
#   'Entity': 'Africa',
#   'Code': nan,
#   'Year': 2023,
#   'Renewables (% equivalent primary energy)': 9.826173},
#  {'_id': ObjectId('680625e5f5024b2c90d00f1c'),
#   'Entity': 'Africa (EI)',
#   'Code': nan,
#   'Year': 1965,
#   'Renewables (% equivalent primary energy)': 5.7402806},
#  {'_id': ObjectId('680625e5f5024b2c90d00f1d'),
#   'Entity': 'Africa (EI)',
#   'Code': nan,
#   'Year': 1966,
#   'Renewables (% equivalent primary energy)': 6.113969},
#  {'_id': ObjectId('680625e5f5024b2c90d00f1e'),
#   'Entity': 'Africa (EI)',
#   'Code': nan,
#   'Year': 1967,
#   'Renewables (% equivalent primary energy)': 6.31658},
#  {'_id': ObjectId('680625e5f5024b2c90d00f1f'),
#   'Entity': 'Africa (EI)',
#   'Code': nan,
#   'Year': 1968,
#   'Renewables (% equivalent primary energy)': 6.994845},
#  {'_id': ObjectId('680625e5f5024b2c90d00f20'),
#   'Entity': 'Africa (EI)',
#   'Code': nan,
#   'Year': 1969,
#   'Renewables (% equivalent primary energy)': 7.9439154},
#  {'_id': ObjectId('680625e5f5024b2c90d00f21'),
#   'Entity': 'Africa (EI)',
#   'Code': nan,
#   'Year': 1970,
#   'Renewables (% equivalent primary energy)': 9.148896},
#  {'_id': ObjectId('680625e5f5024b2c90d00f22'),
#   'Entity': 'Africa (EI)',
#   'Code': nan,
#   'Year': 1971,
#   'Renewables (% equivalent primary energy)': 8.124996},
#  {'_id': ObjectId('680625e5f5024b2c90d00f23'),
#   'Entity': 'Africa (EI)',
#   'Code': nan,
#   'Year': 1972,
#   'Renewables (% equivalent primary energy)': 8.7472725},
#  {'_id': ObjectId('680625e5f5024b2c90d00f24'),
#   'Entity': 'Africa (EI)',
#   'Code': nan,
#   'Year': 1973,
#   'Renewables (% equivalent primary energy)': 8.54162},
#  {'_id': ObjectId('680625e5f5024b2c90d00f25'),
#   'Entity': 'Africa (EI)',
#   'Code': nan,
#   'Year': 1974,
#   'Renewables (% equivalent primary energy)': 9.252388},
#  {'_id': ObjectId('680625e5f5024b2c90d00f26'),
#   'Entity': 'Africa (EI)',
#   'Code': nan,
#   'Year': 1975,
#   'Renewables (% equivalent primary energy)': 9.228768},
#  {'_id': ObjectId('680625e5f5024b2c90d00f27'),
#   'Entity': 'Africa (EI)',
#   'Code': nan,
#   'Year': 1976,
#   'Renewables (% equivalent primary energy)': 9.416379},
#  {'_id': ObjectId('680625e5f5024b2c90d00f28'),
#   'Entity': 'Africa (EI)',
#   'Code': nan,
#   'Year': 1977,
#   'Renewables (% equivalent primary energy)': 9.803097},
#  {'_id': ObjectId('680625e5f5024b2c90d00f29'),
#   'Entity': 'Africa (EI)',
#   'Code': nan,
#   'Year': 1978,
#   'Renewables (% equivalent primary energy)': 9.518462},
#  {'_id': ObjectId('680625e5f5024b2c90d00f2a'),
#   'Entity': 'Africa (EI)',
#   'Code': nan,
#   'Year': 1979,
#   'Renewables (% equivalent primary energy)': 9.349527},
#  {'_id': ObjectId('680625e5f5024b2c90d00f2b'),
#   'Entity': 'Africa (EI)',
#   'Code': nan,
#   'Year': 1980,
#   'Renewables (% equivalent primary energy)': 8.481442},
#  {'_id': ObjectId('680625e5f5024b2c90d00f2c'),
#   'Entity': 'Africa (EI)',
#   'Code': nan,
#   'Year': 1981,
#   'Renewables (% equivalent primary energy)': 7.8527517},
#  {'_id': ObjectId('680625e5f5024b2c90d00f2d'),
#   'Entity': 'Africa (EI)',
#   'Code': nan,
#   'Year': 1982,
#   'Renewables (% equivalent primary energy)': 7.3734274},
#  {'_id': ObjectId('680625e5f5024b2c90d00f2e'),
#   'Entity': 'Africa (EI)',
#   'Code': nan,
#   'Year': 1983,
#   'Renewables (% equivalent primary energy)': 6.456112},
#  {'_id': ObjectId('680625e5f5024b2c90d00f2f'),
#   'Entity': 'Africa (EI)',
#   'Code': nan,
#   'Year': 1984,
#   'Renewables (% equivalent primary energy)': 6.1585774},
#  {'_id': ObjectId('680625e5f5024b2c90d00f30'),
#   'Entity': 'Africa (EI)',
#   'Code': nan,
#   'Year': 1985,
#   'Renewables (% equivalent primary energy)': 6.5793424},
#  {'_id': ObjectId('680625e5f5024b2c90d00f31'),
#   'Entity': 'Africa (EI)',
#   'Code': nan,
#   'Year': 1986,
#   'Renewables (% equivalent primary energy)': 6.7159667},
#  {'_id': ObjectId('680625e5f5024b2c90d00f32'),
#   'Entity': 'Africa (EI)',
#   'Code': nan,
#   'Year': 1987,
#   'Renewables (% equivalent primary energy)': 6.243963},
#  {'_id': ObjectId('680625e5f5024b2c90d00f33'),
#   'Entity': 'Africa (EI)',
#   'Code': nan,
#   'Year': 1988,
#   'Renewables (% equivalent primary energy)': 6.3621163},
#  {'_id': ObjectId('680625e5f5024b2c90d00f34'),
#   'Entity': 'Africa (EI)',
#   'Code': nan,
#   'Year': 1989,
#   'Renewables (% equivalent primary energy)': 6.6654606},
#  {'_id': ObjectId('680625e5f5024b2c90d00f35'),
#   'Entity': 'Africa (EI)',
#   'Code': nan,
#   'Year': 1990,
#   'Renewables (% equivalent primary energy)': 6.5857716},
#  {'_id': ObjectId('680625e5f5024b2c90d00f36'),
#   'Entity': 'Africa (EI)',
#   'Code': nan,
#   'Year': 1991,
#   'Renewables (% equivalent primary energy)': 6.9810143},
#  {'_id': ObjectId('680625e5f5024b2c90d00f37'),
#   'Entity': 'Africa (EI)',
#   'Code': nan,
#   'Year': 1992,
#   'Renewables (% equivalent primary energy)': 6.5694675},
#  {'_id': ObjectId('680625e5f5024b2c90d00f38'),
#   'Entity': 'Africa (EI)',
#   'Code': nan,
#   'Year': 1993,
#   'Renewables (% equivalent primary energy)': 6.43179},
#  {'_id': ObjectId('680625e5f5024b2c90d00f39'),
#   'Entity': 'Africa (EI)',
#   'Code': nan,
#   'Year': 1994,
#   'Renewables (% equivalent primary energy)': 6.3092456},
#  {'_id': ObjectId('680625e5f5024b2c90d00f3a'),
#   'Entity': 'Africa (EI)',
#   'Code': nan,
#   'Year': 1995,
#   'Renewables (% equivalent primary energy)': 6.306244},
#  {'_id': ObjectId('680625e5f5024b2c90d00f3b'),
#   'Entity': 'Africa (EI)',
#   'Code': nan,
#   'Year': 1996,
#   'Renewables (% equivalent primary energy)': 6.433255},
#  {'_id': ObjectId('680625e5f5024b2c90d00f3c'),
#   'Entity': 'Africa (EI)',
#   'Code': nan,
#   'Year': 1997,
#   'Renewables (% equivalent primary energy)': 6.465725},
#  {'_id': ObjectId('680625e5f5024b2c90d00f3d'),
#   'Entity': 'Africa (EI)',
#   'Code': nan,
#   'Year': 1998,
#   'Renewables (% equivalent primary energy)': 6.6761603},
#  {'_id': ObjectId('680625e5f5024b2c90d00f3e'),
#   'Entity': 'Africa (EI)',
#   'Code': nan,
#   'Year': 1999,
#   'Renewables (% equivalent primary energy)': 6.8586307},
#  {'_id': ObjectId('680625e5f5024b2c90d00f3f'),
#   'Entity': 'Africa (EI)',
#   'Code': nan,
#   'Year': 2000,
#   'Renewables (% equivalent primary energy)': 7.2029395},
#  {'_id': ObjectId('680625e5f5024b2c90d00f40'),
#   'Entity': 'Africa (EI)',
#   'Code': nan,
#   'Year': 2001,
#   'Renewables (% equivalent primary energy)': 7.436237},
#  {'_id': ObjectId('680625e5f5024b2c90d00f41'),
#   'Entity': 'Africa (EI)',
#   'Code': nan,
#   'Year': 2002,
#   'Renewables (% equivalent primary energy)': 7.671944},
#  {'_id': ObjectId('680625e5f5024b2c90d00f42'),
#   'Entity': 'Africa (EI)',
#   'Code': nan,
#   'Year': 2003,
#   'Renewables (% equivalent primary energy)': 7.105202},
#  {'_id': ObjectId('680625e5f5024b2c90d00f43'),
#   'Entity': 'Africa (EI)',
#   'Code': nan,
#   'Year': 2004,
#   'Renewables (% equivalent primary energy)': 6.980063},
#  {'_id': ObjectId('680625e5f5024b2c90d00f44'),
#   'Entity': 'Africa (EI)',
#   'Code': nan,
#   'Year': 2005,
#   'Renewables (% equivalent primary energy)': 7.0285006},
#  {'_id': ObjectId('680625e5f5024b2c90d00f45'),
#   'Entity': 'Africa (EI)',
#   'Code': nan,
#   'Year': 2006,
#   'Renewables (% equivalent primary energy)': 7.161177},
#  {'_id': ObjectId('680625e5f5024b2c90d00f46'),
#   'Entity': 'Africa (EI)',
#   'Code': nan,
#   'Year': 2007,
#   'Renewables (% equivalent primary energy)': 7.0572457},
#  {'_id': ObjectId('680625e5f5024b2c90d00f47'),
#   'Entity': 'Africa (EI)',
#   'Code': nan,
#   'Year': 2008,
#   'Renewables (% equivalent primary energy)': 6.761787},
#  {'_id': ObjectId('680625e5f5024b2c90d00f48'),
#   'Entity': 'Africa (EI)',
#   'Code': nan,
#   'Year': 2009,
#   'Renewables (% equivalent primary energy)': 6.8107085},
#  {'_id': ObjectId('680625e5f5024b2c90d00f49'),
#   'Entity': 'Africa (EI)',
#   'Code': nan,
#   'Year': 2010,
#   'Renewables (% equivalent primary energy)': 7.12904},
#  {'_id': ObjectId('680625e5f5024b2c90d00f4a'),
#   'Entity': 'Africa (EI)',
#   'Code': nan,
#   'Year': 2011,
#   'Renewables (% equivalent primary energy)': 7.2594023},
#  {'_id': ObjectId('680625e5f5024b2c90d00f4b'),
#   'Entity': 'Africa (EI)',
#   'Code': nan,
#   'Year': 2012,
#   'Renewables (% equivalent primary energy)': 6.9972486},
#  {'_id': ObjectId('680625e5f5024b2c90d00f4c'),
#   'Entity': 'Africa (EI)',
#   'Code': nan,
#   'Year': 2013,
#   'Renewables (% equivalent primary energy)': 7.189637},
#  {'_id': ObjectId('680625e5f5024b2c90d00f4d'),
#   'Entity': 'Africa (EI)',
#   'Code': nan,
#   'Year': 2014,
#   'Renewables (% equivalent primary energy)': 7.5156765},
#  {'_id': ObjectId('680625e5f5024b2c90d00f4e'),
#   'Entity': 'Africa (EI)',
#   'Code': nan,
#   'Year': 2015,
#   'Renewables (% equivalent primary energy)': 7.527505},
#  {'_id': ObjectId('680625e5f5024b2c90d00f4f'),
#   'Entity': 'Africa (EI)',
#   'Code': nan,
#   'Year': 2016,
#   'Renewables (% equivalent primary energy)': 7.404273},
#  {'_id': ObjectId('680625e5f5024b2c90d00f50'),
#   'Entity': 'Africa (EI)',
#   'Code': nan,
#   'Year': 2017,
#   'Renewables (% equivalent primary energy)': 7.6419473},
#  {'_id': ObjectId('680625e5f5024b2c90d00f51'),
#   'Entity': 'Africa (EI)',
#   'Code': nan,
#   'Year': 2018,
#   'Renewables (% equivalent primary energy)': 8.005553},
#  {'_id': ObjectId('680625e5f5024b2c90d00f52'),
#   'Entity': 'Africa (EI)',
#   'Code': nan,
#   'Year': 2019,
#   'Renewables (% equivalent primary energy)': 8.356321},
#  {'_id': ObjectId('680625e5f5024b2c90d00f53'),
#   'Entity': 'Africa (EI)',
#   'Code': nan,
#   'Year': 2020,
#   'Renewables (% equivalent primary energy)': 9.415897},
#  {'_id': ObjectId('680625e5f5024b2c90d00f54'),
#   'Entity': 'Africa (EI)',
#   'Code': nan,
#   'Year': 2021,
#   'Renewables (% equivalent primary energy)': 9.152214},
#  {'_id': ObjectId('680625e5f5024b2c90d00f55'),
#   'Entity': 'Africa (EI)',
#   'Code': nan,
#   'Year': 2022,
#   'Renewables (% equivalent primary energy)': 9.298185},
#  {'_id': ObjectId('680625e5f5024b2c90d00f56'),
#   'Entity': 'Africa (EI)',
#   'Code': nan,
#   'Year': 2023,
#   'Renewables (% equivalent primary energy)': 9.826172},
#  {'_id': ObjectId('680625e5f5024b2c90d00f57'),
#   'Entity': 'Algeria',
#   'Code': 'DZA',
#   'Year': 1965,
#   'Renewables (% equivalent primary energy)': 4.7630677},
#  {'_id': ObjectId('680625e5f5024b2c90d00f58'),
#   'Entity': 'Algeria',
#   'Code': 'DZA',
#   'Year': 1966,
#   'Renewables (% equivalent primary energy)': 3.518747},
#  {'_id': ObjectId('680625e5f5024b2c90d00f59'),
#   'Entity': 'Algeria',
#   'Code': 'DZA',
#   'Year': 1967,
#   'Renewables (% equivalent primary energy)': 4.291954},
#  {'_id': ObjectId('680625e5f5024b2c90d00f5a'),
#   'Entity': 'Algeria',
#   'Code': 'DZA',
#   'Year': 1968,
#   'Renewables (% equivalent primary energy)': 5.4861946},
#  {'_id': ObjectId('680625e5f5024b2c90d00f5b'),
#   'Entity': 'Algeria',
#   'Code': 'DZA',
#   'Year': 1969,
#   'Renewables (% equivalent primary energy)': 3.1827633},
#  {'_id': ObjectId('680625e5f5024b2c90d00f5c'),
#   'Entity': 'Algeria',
#   'Code': 'DZA',
#   'Year': 1970,
#   'Renewables (% equivalent primary energy)': 4.6656837},
#  {'_id': ObjectId('680625e5f5024b2c90d00f5d'),
#   'Entity': 'Algeria',
#   'Code': 'DZA',
#   'Year': 1971,
#   'Renewables (% equivalent primary energy)': 2.4559188},
#  {'_id': ObjectId('680625e5f5024b2c90d00f5e'),
#   'Entity': 'Algeria',
#   'Code': 'DZA',
#   'Year': 1972,
#   'Renewables (% equivalent primary energy)': 3.278343},
#  {'_id': ObjectId('680625e5f5024b2c90d00f5f'),
#   'Entity': 'Algeria',
#   'Code': 'DZA',
#   'Year': 1973,
#   'Renewables (% equivalent primary energy)': 4.175826},
#  {'_id': ObjectId('680625e5f5024b2c90d00f60'),
#   'Entity': 'Algeria',
#   'Code': 'DZA',
#   'Year': 1974,
#   'Renewables (% equivalent primary energy)': 2.494738},
#  {'_id': ObjectId('680625e5f5024b2c90d00f61'),
#   'Entity': 'Algeria',
#   'Code': 'DZA',
#   'Year': 1975,
#   'Renewables (% equivalent primary energy)': 1.3782818},
#  {'_id': ObjectId('680625e5f5024b2c90d00f62'),
#   'Entity': 'Algeria',
#   'Code': 'DZA',
#   'Year': 1976,
#   'Renewables (% equivalent primary energy)': 1.4010222},
#  {'_id': ObjectId('680625e5f5024b2c90d00f63'),
#   'Entity': 'Algeria',
#   'Code': 'DZA',
#   'Year': 1977,
#   'Renewables (% equivalent primary energy)': 0.8817282},
#  {'_id': ObjectId('680625e5f5024b2c90d00f64'),
#   'Entity': 'Algeria',
#   'Code': 'DZA',
#   'Year': 1978,
#   'Renewables (% equivalent primary energy)': 0.6521151},
#  {'_id': ObjectId('680625e5f5024b2c90d00f65'),
#   'Entity': 'Algeria',
#   'Code': 'DZA',
#   'Year': 1979,
#   'Renewables (% equivalent primary energy)': 0.5792936},
#  {'_id': ObjectId('680625e5f5024b2c90d00f66'),
#   'Entity': 'Algeria',
#   'Code': 'DZA',
#   'Year': 1980,
#   'Renewables (% equivalent primary energy)': 0.4290016},
#  {'_id': ObjectId('680625e5f5024b2c90d00f67'),
#   'Entity': 'Algeria',
#   'Code': 'DZA',
#   'Year': 1981,
#   'Renewables (% equivalent primary energy)': 0.50294036},
#  {'_id': ObjectId('680625e5f5024b2c90d00f68'),
#   'Entity': 'Algeria',
#   'Code': 'DZA',
#   'Year': 1982,
#   'Renewables (% equivalent primary energy)': 0.5708701},
#  {'_id': ObjectId('680625e5f5024b2c90d00f69'),
#   'Entity': 'Algeria',
#   'Code': 'DZA',
#   'Year': 1983,
#   'Renewables (% equivalent primary energy)': 0.25644946},
#  {'_id': ObjectId('680625e5f5024b2c90d00f6a'),
#   'Entity': 'Algeria',
#   'Code': 'DZA',
#   'Year': 1984,
#   'Renewables (% equivalent primary energy)': 0.5136736},
#  {'_id': ObjectId('680625e5f5024b2c90d00f6b'),
#   'Entity': 'Algeria',
#   'Code': 'DZA',
#   'Year': 1985,
#   'Renewables (% equivalent primary energy)': 0.72826535},
#  {'_id': ObjectId('680625e5f5024b2c90d00f6c'),
#   'Entity': 'Algeria',
#   'Code': 'DZA',
#   'Year': 1986,
#   'Renewables (% equivalent primary energy)': 0.2664045},
#  {'_id': ObjectId('680625e5f5024b2c90d00f6d'),
#   'Entity': 'Algeria',
#   'Code': 'DZA',
#   'Year': 1987,
#   'Renewables (% equivalent primary energy)': 0.5174274},
#  {'_id': ObjectId('680625e5f5024b2c90d00f6e'),
#   'Entity': 'Algeria',
#   'Code': 'DZA',
#   'Year': 1988,
#   'Renewables (% equivalent primary energy)': 0.17717436},
#  {'_id': ObjectId('680625e5f5024b2c90d00f6f'),
#   'Entity': 'Algeria',
#   'Code': 'DZA',
#   'Year': 1989,
#   'Renewables (% equivalent primary energy)': 0.2249582},
#  {'_id': ObjectId('680625e5f5024b2c90d00f70'),
#   'Entity': 'Algeria',
#   'Code': 'DZA',
#   'Year': 1990,
#   'Renewables (% equivalent primary energy)': 0.1267387},
#  {'_id': ObjectId('680625e5f5024b2c90d00f71'),
#   'Entity': 'Algeria',
#   'Code': 'DZA',
#   'Year': 1991,
#   'Renewables (% equivalent primary energy)': 0.277607},
#  {'_id': ObjectId('680625e5f5024b2c90d00f72'),
#   'Entity': 'Algeria',
#   'Code': 'DZA',
#   'Year': 1992,
#   'Renewables (% equivalent primary energy)': 0.18375748},
#  {'_id': ObjectId('680625e5f5024b2c90d00f73'),
#   'Entity': 'Algeria',
#   'Code': 'DZA',
#   'Year': 1993,
#   'Renewables (% equivalent primary energy)': 0.35028014},
#  {'_id': ObjectId('680625e5f5024b2c90d00f74'),
#   'Entity': 'Algeria',
#   'Code': 'DZA',
#   'Year': 1994,
#   'Renewables (% equivalent primary energy)': 0.16257899},
#  {'_id': ObjectId('680625e5f5024b2c90d00f75'),
#   'Entity': 'Algeria',
#   'Code': 'DZA',
#   'Year': 1995,
#   'Renewables (% equivalent primary energy)': 0.18224756},
#  {'_id': ObjectId('680625e5f5024b2c90d00f76'),
#   'Entity': 'Algeria',
#   'Code': 'DZA',
#   'Year': 1996,
#   'Renewables (% equivalent primary energy)': 0.1288034},
#  {'_id': ObjectId('680625e5f5024b2c90d00f77'),
#   'Entity': 'Algeria',
#   'Code': 'DZA',
#   'Year': 1997,
#   'Renewables (% equivalent primary energy)': 0.074455895},
#  {'_id': ObjectId('680625e5f5024b2c90d00f78'),
#   'Entity': 'Algeria',
#   'Code': 'DZA',
#   'Year': 1998,
#   'Renewables (% equivalent primary energy)': 0.20617963},
#  {'_id': ObjectId('680625e5f5024b2c90d00f79'),
#   'Entity': 'Algeria',
#   'Code': 'DZA',
#   'Year': 1999,
#   'Renewables (% equivalent primary energy)': 0.1927434},
#  {'_id': ObjectId('680625e5f5024b2c90d00f7a'),
#   'Entity': 'Algeria',
#   'Code': 'DZA',
#   'Year': 2000,
#   'Renewables (% equivalent primary energy)': 0.053235486},
#  {'_id': ObjectId('680625e5f5024b2c90d00f7b'),
#   'Entity': 'Algeria',
#   'Code': 'DZA',
#   'Year': 2001,
#   'Renewables (% equivalent primary energy)': 0.065218486},
#  {'_id': ObjectId('680625e5f5024b2c90d00f7c'),
#   'Entity': 'Algeria',
#   'Code': 'DZA',
#   'Year': 2002,
#   'Renewables (% equivalent primary energy)': 0.05167676},
#  {'_id': ObjectId('680625e5f5024b2c90d00f7d'),
#   'Entity': 'Algeria',
#   'Code': 'DZA',
#   'Year': 2003,
#   'Renewables (% equivalent primary energy)': 0.228104},
#  {'_id': ObjectId('680625e5f5024b2c90d00f7e'),
#   'Entity': 'Algeria',
#   'Code': 'DZA',
#   'Year': 2004,
#   'Renewables (% equivalent primary energy)': 0.2067869},
#  {'_id': ObjectId('680625e5f5024b2c90d00f7f'),
#   'Entity': 'Algeria',
#   'Code': 'DZA',
#   'Year': 2005,
#   'Renewables (% equivalent primary energy)': 0.43411884},
#  {'_id': ObjectId('680625e5f5024b2c90d00f80'),
#   'Entity': 'Algeria',
#   'Code': 'DZA',
#   'Year': 2006,
#   'Renewables (% equivalent primary energy)': 0.16327195},
#  {'_id': ObjectId('680625e5f5024b2c90d00f81'),
#   'Entity': 'Algeria',
#   'Code': 'DZA',
#   'Year': 2007,
#   'Renewables (% equivalent primary energy)': 0.15990457},
#  {'_id': ObjectId('680625e5f5024b2c90d00f82'),
#   'Entity': 'Algeria',
#   'Code': 'DZA',
#   'Year': 2008,
#   'Renewables (% equivalent primary energy)': 0.1877543},
#  {'_id': ObjectId('680625e5f5024b2c90d00f83'),
#   'Entity': 'Algeria',
#   'Code': 'DZA',
#   'Year': 2009,
#   'Renewables (% equivalent primary energy)': 0.21278548},
#  {'_id': ObjectId('680625e5f5024b2c90d00f84'),
#   'Entity': 'Algeria',
#   'Code': 'DZA',
#   'Year': 2010,
#   'Renewables (% equivalent primary energy)': 0.11513415},
#  {'_id': ObjectId('680625e5f5024b2c90d00f85'),
#   'Entity': 'Algeria',
#   'Code': 'DZA',
#   'Year': 2011,
#   'Renewables (% equivalent primary energy)': 0.23525994},
#  {'_id': ObjectId('680625e5f5024b2c90d00f86'),
#   'Entity': 'Algeria',
#   'Code': 'DZA',
#   'Year': 2012,
#   'Renewables (% equivalent primary energy)': 0.22453195},
#  {'_id': ObjectId('680625e5f5024b2c90d00f87'),
#   'Entity': 'Algeria',
#   'Code': 'DZA',
#   'Year': 2013,
#   'Renewables (% equivalent primary energy)': 0.06476319},
#  {'_id': ObjectId('680625e5f5024b2c90d00f88'),
#   'Entity': 'Algeria',
#   'Code': 'DZA',
#   'Year': 2014,
#   'Renewables (% equivalent primary energy)': 0.11750259},
#  {'_id': ObjectId('680625e5f5024b2c90d00f89'),
#   'Entity': 'Algeria',
#   'Code': 'DZA',
#   'Year': 2015,
#   'Renewables (% equivalent primary energy)': 0.09681336},
#  {'_id': ObjectId('680625e5f5024b2c90d00f8a'),
#   'Entity': 'Algeria',
#   'Code': 'DZA',
#   'Year': 2016,
#   'Renewables (% equivalent primary energy)': 0.14580713},
#  {'_id': ObjectId('680625e5f5024b2c90d00f8b'),
#   'Entity': 'Algeria',
#   'Code': 'DZA',
#   'Year': 2017,
#   'Renewables (% equivalent primary energy)': 0.24701828},
#  {'_id': ObjectId('680625e5f5024b2c90d00f8c'),
#   'Entity': 'Algeria',
#   'Code': 'DZA',
#   'Year': 2018,
#   'Renewables (% equivalent primary energy)': 0.28842947},
#  {'_id': ObjectId('680625e5f5024b2c90d00f8d'),
#   'Entity': 'Algeria',
#   'Code': 'DZA',
#   'Year': 2019,
#   'Renewables (% equivalent primary energy)': 0.29497427},
#  {'_id': ObjectId('680625e5f5024b2c90d00f8e'),
#   'Entity': 'Algeria',
#   'Code': 'DZA',
#   'Year': 2020,
#   'Renewables (% equivalent primary energy)': 0.30043116},
#  {'_id': ObjectId('680625e5f5024b2c90d00f8f'),
#   'Entity': 'Algeria',
#   'Code': 'DZA',
#   'Year': 2021,
#   'Renewables (% equivalent primary energy)': 0.25285673},
#  {'_id': ObjectId('680625e5f5024b2c90d00f90'),
#   'Entity': 'Algeria',
#   'Code': 'DZA',
#   'Year': 2022,
#   'Renewables (% equivalent primary energy)': 0.24182516},
#  {'_id': ObjectId('680625e5f5024b2c90d00f91'),
#   'Entity': 'Algeria',
#   'Code': 'DZA',
#   'Year': 2023,
#   'Renewables (% equivalent primary energy)': 0.27036947},
#  {'_id': ObjectId('680625e5f5024b2c90d00f92'),
#   'Entity': 'Argentina',
#   'Code': 'ARG',
#   'Year': 1965,
#   'Renewables (% equivalent primary energy)': 1.1026944},
#  {'_id': ObjectId('680625e5f5024b2c90d00f93'),
#   'Entity': 'Argentina',
#   'Code': 'ARG',
#   'Year': 1966,
#   'Renewables (% equivalent primary energy)': 1.0818663},
#  {'_id': ObjectId('680625e5f5024b2c90d00f94'),
#   'Entity': 'Argentina',
#   'Code': 'ARG',
#   'Year': 1967,
#   'Renewables (% equivalent primary energy)': 1.0765308},
#  {'_id': ObjectId('680625e5f5024b2c90d00f95'),
#   'Entity': 'Argentina',
#   'Code': 'ARG',
#   'Year': 1968,
#   'Renewables (% equivalent primary energy)': 1.2272897},
#  {'_id': ObjectId('680625e5f5024b2c90d00f96'),
#   'Entity': 'Argentina',
#   'Code': 'ARG',
#   'Year': 1969,
#   'Renewables (% equivalent primary energy)': 1.0651326},
#  {'_id': ObjectId('680625e5f5024b2c90d00f97'),
#   'Entity': 'Argentina',
#   'Code': 'ARG',
#   'Year': 1970,
#   'Renewables (% equivalent primary energy)': 1.3533598},
#  {'_id': ObjectId('680625e5f5024b2c90d00f98'),
#   'Entity': 'Argentina',
#   'Code': 'ARG',
#   'Year': 1971,
#   'Renewables (% equivalent primary energy)': 1.2702763},
#  {'_id': ObjectId('680625e5f5024b2c90d00f99'),
#   'Entity': 'Argentina',
#   'Code': 'ARG',
#   'Year': 1972,
#   'Renewables (% equivalent primary energy)': 1.2349532},
#  {'_id': ObjectId('680625e5f5024b2c90d00f9a'),
#   'Entity': 'Argentina',
#   'Code': 'ARG',
#   'Year': 1973,
#   'Renewables (% equivalent primary energy)': 2.2839267},
#  {'_id': ObjectId('680625e5f5024b2c90d00f9b'),
#   'Entity': 'Argentina',
#   'Code': 'ARG',
#   'Year': 1974,
#   'Renewables (% equivalent primary energy)': 3.629566},
#  {'_id': ObjectId('680625e5f5024b2c90d00f9c'),
#   'Entity': 'Argentina',
#   'Code': 'ARG',
#   'Year': 1975,
#   'Renewables (% equivalent primary energy)': 3.8664374},
#  {'_id': ObjectId('680625e5f5024b2c90d00f9d'),
#   'Entity': 'Argentina',
#   'Code': 'ARG',
#   'Year': 1976,
#   'Renewables (% equivalent primary energy)': 3.5540857},
#  {'_id': ObjectId('680625e5f5024b2c90d00f9e'),
#   'Entity': 'Argentina',
#   'Code': 'ARG',
#   'Year': 1977,
#   'Renewables (% equivalent primary energy)': 3.9090023},
#  {'_id': ObjectId('680625e5f5024b2c90d00f9f'),
#   'Entity': 'Argentina',
#   'Code': 'ARG',
#   'Year': 1978,
#   'Renewables (% equivalent primary energy)': 5.227204},
#  {'_id': ObjectId('680625e5f5024b2c90d00fa0'),
#   'Entity': 'Argentina',
#   'Code': 'ARG',
#   'Year': 1979,
#   'Renewables (% equivalent primary energy)': 6.702873},
#  {'_id': ObjectId('680625e5f5024b2c90d00fa1'),
#   'Entity': 'Argentina',
#   'Code': 'ARG',
#   'Year': 1980,
#   'Renewables (% equivalent primary energy)': 9.552048},
#  {'_id': ObjectId('680625e5f5024b2c90d00fa2'),
#   'Entity': 'Argentina',
#   'Code': 'ARG',
#   'Year': 1981,
#   'Renewables (% equivalent primary energy)': 9.542367},
#  {'_id': ObjectId('680625e5f5024b2c90d00fa3'),
#   'Entity': 'Argentina',
#   'Code': 'ARG',
#   'Year': 1982,
#   'Renewables (% equivalent primary energy)': 11.229478},
#  {'_id': ObjectId('680625e5f5024b2c90d00fa4'),
#   'Entity': 'Argentina',
#   'Code': 'ARG',
#   'Year': 1983,
#   'Renewables (% equivalent primary energy)': 11.313745},
#  {'_id': ObjectId('680625e5f5024b2c90d00fa5'),
#   'Entity': 'Argentina',
#   'Code': 'ARG',
#   'Year': 1984,
#   'Renewables (% equivalent primary energy)': 12.136334},
#  {'_id': ObjectId('680625e5f5024b2c90d00fa6'),
#   'Entity': 'Argentina',
#   'Code': 'ARG',
#   'Year': 1985,
#   'Renewables (% equivalent primary energy)': 12.759911},
#  {'_id': ObjectId('680625e5f5024b2c90d00fa7'),
#   'Entity': 'Argentina',
#   'Code': 'ARG',
#   'Year': 1986,
#   'Renewables (% equivalent primary energy)': 12.297877},
#  {'_id': ObjectId('680625e5f5024b2c90d00fa8'),
#   'Entity': 'Argentina',
#   'Code': 'ARG',
#   'Year': 1987,
#   'Renewables (% equivalent primary energy)': 12.24687},
#  {'_id': ObjectId('680625e5f5024b2c90d00fa9'),
#   'Entity': 'Argentina',
#   'Code': 'ARG',
#   'Year': 1988,
#   'Renewables (% equivalent primary energy)': 8.416951},
#  {'_id': ObjectId('680625e5f5024b2c90d00faa'),
#   'Entity': 'Argentina',
#   'Code': 'ARG',
#   'Year': 1989,
#   'Renewables (% equivalent primary energy)': 7.543206},
#  {'_id': ObjectId('680625e5f5024b2c90d00fab'),
#   'Entity': 'Argentina',
#   'Code': 'ARG',
#   'Year': 1990,
#   'Renewables (% equivalent primary energy)': 10.29241},
#  {'_id': ObjectId('680625e5f5024b2c90d00fac'),
#   'Entity': 'Argentina',
#   'Code': 'ARG',
#   'Year': 1991,
#   'Renewables (% equivalent primary energy)': 9.080978},
#  {'_id': ObjectId('680625e5f5024b2c90d00fad'),
#   'Entity': 'Argentina',
#   'Code': 'ARG',
#   'Year': 1992,
#   'Renewables (% equivalent primary energy)': 10.2065},
#  {'_id': ObjectId('680625e5f5024b2c90d00fae'),
#   'Entity': 'Argentina',
#   'Code': 'ARG',
#   'Year': 1993,
#   'Renewables (% equivalent primary energy)': 12.215968},
#  {'_id': ObjectId('680625e5f5024b2c90d00faf'),
#   'Entity': 'Argentina',
#   'Code': 'ARG',
#   'Year': 1994,
#   'Renewables (% equivalent primary energy)': 13.306112},
#  {'_id': ObjectId('680625e5f5024b2c90d00fb0'),
#   'Entity': 'Argentina',
#   'Code': 'ARG',
#   'Year': 1995,
#   'Renewables (% equivalent primary energy)': 12.535252},
#  {'_id': ObjectId('680625e5f5024b2c90d00fb1'),
#   'Entity': 'Argentina',
#   'Code': 'ARG',
#   'Year': 1996,
#   'Renewables (% equivalent primary energy)': 10.224623},
#  {'_id': ObjectId('680625e5f5024b2c90d00fb2'),
#   'Entity': 'Argentina',
#   'Code': 'ARG',
#   'Year': 1997,
#   'Renewables (% equivalent primary energy)': 12.513889},
#  {'_id': ObjectId('680625e5f5024b2c90d00fb3'),
#   'Entity': 'Argentina',
#   'Code': 'ARG',
#   'Year': 1998,
#   'Renewables (% equivalent primary energy)': 11.481932},
#  {'_id': ObjectId('680625e5f5024b2c90d00fb4'),
#   'Entity': 'Argentina',
#   'Code': 'ARG',
#   'Year': 1999,
#   'Renewables (% equivalent primary energy)': 9.2246065},
#  {'_id': ObjectId('680625e5f5024b2c90d00fb5'),
#   'Entity': 'Argentina',
#   'Code': 'ARG',
#   'Year': 2000,
#   'Renewables (% equivalent primary energy)': 12.283152},
#  {'_id': ObjectId('680625e5f5024b2c90d00fb6'),
#   'Entity': 'Argentina',
#   'Code': 'ARG',
#   'Year': 2001,
#   'Renewables (% equivalent primary energy)': 15.93624},
#  {'_id': ObjectId('680625e5f5024b2c90d00fb7'),
#   'Entity': 'Argentina',
#   'Code': 'ARG',
#   'Year': 2002,
#   'Renewables (% equivalent primary energy)': 16.247978},
#  {'_id': ObjectId('680625e5f5024b2c90d00fb8'),
#   'Entity': 'Argentina',
#   'Code': 'ARG',
#   'Year': 2003,
#   'Renewables (% equivalent primary energy)': 14.40661},
#  {'_id': ObjectId('680625e5f5024b2c90d00fb9'),
#   'Entity': 'Argentina',
#   'Code': 'ARG',
#   'Year': 2004,
#   'Renewables (% equivalent primary energy)': 12.185576},
#  {'_id': ObjectId('680625e5f5024b2c90d00fba'),
#   'Entity': 'Argentina',
#   'Code': 'ARG',
#   'Year': 2005,
#   'Renewables (% equivalent primary energy)': 12.790038},
#  {'_id': ObjectId('680625e5f5024b2c90d00fbb'),
#   'Entity': 'Argentina',
#   'Code': 'ARG',
#   'Year': 2006,
#   'Renewables (% equivalent primary energy)': 13.449896},
#  {'_id': ObjectId('680625e5f5024b2c90d00fbc'),
#   'Entity': 'Argentina',
#   'Code': 'ARG',
#   'Year': 2007,
#   'Renewables (% equivalent primary energy)': 10.613073},
#  {'_id': ObjectId('680625e5f5024b2c90d00fbd'),
#   'Entity': 'Argentina',
#   'Code': 'ARG',
#   'Year': 2008,
#   'Renewables (% equivalent primary energy)': 10.447249},
#  {'_id': ObjectId('680625e5f5024b2c90d00fbe'),
#   'Entity': 'Argentina',
#   'Code': 'ARG',
#   'Year': 2009,
#   'Renewables (% equivalent primary energy)': 11.797741},
#  {'_id': ObjectId('680625e5f5024b2c90d00fbf'),
#   'Entity': 'Argentina',
#   'Code': 'ARG',
#   'Year': 2010,
#   'Renewables (% equivalent primary energy)': 11.650168},
#  {'_id': ObjectId('680625e5f5024b2c90d00fc0'),
#   'Entity': 'Argentina',
#   'Code': 'ARG',
#   'Year': 2011,
#   'Renewables (% equivalent primary energy)': 10.914268},
#  {'_id': ObjectId('680625e5f5024b2c90d00fc1'),
#   'Entity': 'Argentina',
#   'Code': 'ARG',
#   'Year': 2012,
#   'Renewables (% equivalent primary energy)': 10.176803},
#  {'_id': ObjectId('680625e5f5024b2c90d00fc2'),
#   'Entity': 'Argentina',
#   'Code': 'ARG',
#   'Year': 2013,
#   'Renewables (% equivalent primary energy)': 10.940409},
#  {'_id': ObjectId('680625e5f5024b2c90d00fc3'),
#   'Entity': 'Argentina',
#   'Code': 'ARG',
#   'Year': 2014,
#   'Renewables (% equivalent primary energy)': 11.038969},
#  {'_id': ObjectId('680625e5f5024b2c90d00fc4'),
#   'Entity': 'Argentina',
#   'Code': 'ARG',
#   'Year': 2015,
#   'Renewables (% equivalent primary energy)': 10.89336},
#  {'_id': ObjectId('680625e5f5024b2c90d00fc5'),
#   'Entity': 'Argentina',
#   'Code': 'ARG',
#   'Year': 2016,
#   'Renewables (% equivalent primary energy)': 10.17179},
#  {'_id': ObjectId('680625e5f5024b2c90d00fc6'),
#   'Entity': 'Argentina',
#   'Code': 'ARG',
#   'Year': 2017,
#   'Renewables (% equivalent primary energy)': 10.979133},
#  {'_id': ObjectId('680625e5f5024b2c90d00fc7'),
#   'Entity': 'Argentina',
#   'Code': 'ARG',
#   'Year': 2018,
#   'Renewables (% equivalent primary energy)': 11.331651},
#  {'_id': ObjectId('680625e5f5024b2c90d00fc8'),
#   'Entity': 'Argentina',
#   'Code': 'ARG',
#   'Year': 2019,
#   'Renewables (% equivalent primary energy)': 11.911147},
#  {'_id': ObjectId('680625e5f5024b2c90d00fc9'),
#   'Entity': 'Argentina',
#   'Code': 'ARG',
#   'Year': 2020,
#   'Renewables (% equivalent primary energy)': 12.310073},
#  {'_id': ObjectId('680625e5f5024b2c90d00fca'),
#   'Entity': 'Argentina',
#   'Code': 'ARG',
#   'Year': 2021,
#   'Renewables (% equivalent primary energy)': 11.335143},
#  {'_id': ObjectId('680625e5f5024b2c90d00fcb'),
#   'Entity': 'Argentina',
#   'Code': 'ARG',
#   'Year': 2022,
#   'Renewables (% equivalent primary energy)': 12.188763},
#  {'_id': ObjectId('680625e5f5024b2c90d00fcc'),
#   'Entity': 'Argentina',
#   'Code': 'ARG',
#   'Year': 2023,
#   'Renewables (% equivalent primary energy)': 14.102216},
#  {'_id': ObjectId('680625e5f5024b2c90d00fcd'),
#   'Entity': 'Asia',
#   'Code': nan,
#   'Year': 1965,
#   'Renewables (% equivalent primary energy)': 7.8735447},
#  {'_id': ObjectId('680625e5f5024b2c90d00fce'),
#   'Entity': 'Asia',
#   'Code': nan,
#   'Year': 1966,
#   'Renewables (% equivalent primary energy)': 7.4938087},
#  {'_id': ObjectId('680625e5f5024b2c90d00fcf'),
#   'Entity': 'Asia',
#   'Code': nan,
#   'Year': 1967,
#   'Renewables (% equivalent primary energy)': 6.7346387},
#  {'_id': ObjectId('680625e5f5024b2c90d00fd0'),
#   'Entity': 'Asia',
#   'Code': nan,
#   'Year': 1968,
#   'Renewables (% equivalent primary energy)': 6.963028},
#  {'_id': ObjectId('680625e5f5024b2c90d00fd1'),
#   'Entity': 'Asia',
#   'Code': nan,
#   'Year': 1969,
#   'Renewables (% equivalent primary energy)': 6.3012996},
#  {'_id': ObjectId('680625e5f5024b2c90d00fd2'),
#   'Entity': 'Asia',
#   'Code': nan,
#   'Year': 1970,
#   'Renewables (% equivalent primary energy)': 5.661888},
#  {'_id': ObjectId('680625e5f5024b2c90d00fd3'),
#   'Entity': 'Asia',
#   'Code': nan,
#   'Year': 1971,
#   'Renewables (% equivalent primary energy)': 5.6825113},
#  {'_id': ObjectId('680625e5f5024b2c90d00fd4'),
#   'Entity': 'Asia',
#   'Code': nan,
#   'Year': 1972,
#   'Renewables (% equivalent primary energy)': 5.4817533},
#  {'_id': ObjectId('680625e5f5024b2c90d00fd5'),
#   'Entity': 'Asia',
#   'Code': nan,
#   'Year': 1973,
#   'Renewables (% equivalent primary energy)': 4.7254024},
#  {'_id': ObjectId('680625e5f5024b2c90d00fd6'),
#   'Entity': 'Asia',
#   'Code': nan,
#   'Year': 1974,
#   'Renewables (% equivalent primary energy)': 5.289435},
#  {'_id': ObjectId('680625e5f5024b2c90d00fd7'),
#   'Entity': 'Asia',
#   'Code': nan,
#   'Year': 1975,
#   'Renewables (% equivalent primary energy)': 5.432976},
#  {'_id': ObjectId('680625e5f5024b2c90d00fd8'),
#   'Entity': 'Asia',
#   'Code': nan,
#   'Year': 1976,
#   'Renewables (% equivalent primary energy)': 5.272847},
#  {'_id': ObjectId('680625e5f5024b2c90d00fd9'),
#   'Entity': 'Asia',
#   'Code': nan,
#   'Year': 1977,
#   'Renewables (% equivalent primary energy)': 4.885452},
#  {'_id': ObjectId('680625e5f5024b2c90d00fda'),
#   'Entity': 'Asia',
#   'Code': nan,
#   'Year': 1978,
#   'Renewables (% equivalent primary energy)': 4.842396},
#  {'_id': ObjectId('680625e5f5024b2c90d00fdb'),
#   'Entity': 'Asia',
#   'Code': nan,
#   'Year': 1979,
#   'Renewables (% equivalent primary energy)': 5.0050187},
#  {'_id': ObjectId('680625e5f5024b2c90d00fdc'),
#   'Entity': 'Asia',
#   'Code': nan,
#   'Year': 1980,
#   'Renewables (% equivalent primary energy)': 5.387261},
#  {'_id': ObjectId('680625e5f5024b2c90d00fdd'),
#   'Entity': 'Asia',
#   'Code': nan,
#   'Year': 1981,
#   'Renewables (% equivalent primary energy)': 5.6962633},
#  {'_id': ObjectId('680625e5f5024b2c90d00fde'),
#   'Entity': 'Asia',
#   'Code': nan,
#   'Year': 1982,
#   'Renewables (% equivalent primary energy)': 5.688111},
#  {'_id': ObjectId('680625e5f5024b2c90d00fdf'),
#   'Entity': 'Asia',
#   'Code': nan,
#   'Year': 1983,
#   'Renewables (% equivalent primary energy)': 5.652118},
#  {'_id': ObjectId('680625e5f5024b2c90d00fe0'),
#   'Entity': 'Asia',
#   'Code': nan,
#   'Year': 1984,
#   'Renewables (% equivalent primary energy)': 5.339281},
#  {'_id': ObjectId('680625e5f5024b2c90d00fe1'),
#   'Entity': 'Asia',
#   'Code': nan,
#   'Year': 1985,
#   'Renewables (% equivalent primary energy)': 5.351906},
#  {'_id': ObjectId('680625e5f5024b2c90d00fe2'),
#   'Entity': 'Asia',
#   'Code': nan,
#   'Year': 1986,
#   'Renewables (% equivalent primary energy)': 5.190978},
#  {'_id': ObjectId('680625e5f5024b2c90d00fe3'),
#   'Entity': 'Asia',
#   'Code': nan,
#   'Year': 1987,
#   'Renewables (% equivalent primary energy)': 5.0590653},
#  {'_id': ObjectId('680625e5f5024b2c90d00fe4'),
#   'Entity': 'Asia',
#   'Code': nan,
#   'Year': 1988,
#   'Renewables (% equivalent primary energy)': 5.4249687},
#  {'_id': ObjectId('680625e5f5024b2c90d00fe5'),
#   'Entity': 'Asia',
#   'Code': nan,
#   'Year': 1989,
#   'Renewables (% equivalent primary energy)': 5.319675},
#  {'_id': ObjectId('680625e5f5024b2c90d00fe6'),
#   'Entity': 'Asia',
#   'Code': nan,
#   'Year': 1990,
#   'Renewables (% equivalent primary energy)': 5.339282},
#  {'_id': ObjectId('680625e5f5024b2c90d00fe7'),
#   'Entity': 'Asia',
#   'Code': nan,
#   'Year': 1991,
#   'Renewables (% equivalent primary energy)': 5.1891055},
#  {'_id': ObjectId('680625e5f5024b2c90d00fe8'),
#   'Entity': 'Asia',
#   'Code': nan,
#   'Year': 1992,
#   'Renewables (% equivalent primary energy)': 5.0055637},
#  {'_id': ObjectId('680625e5f5024b2c90d00fe9'),
#   'Entity': 'Asia',
#   'Code': nan,
#   'Year': 1993,
#   'Renewables (% equivalent primary energy)': 5.3127103},
#  {'_id': ObjectId('680625e5f5024b2c90d00fea'),
#   'Entity': 'Asia',
#   'Code': nan,
#   'Year': 1994,
#   'Renewables (% equivalent primary energy)': 5.0516157},
#  {'_id': ObjectId('680625e5f5024b2c90d00feb'),
#   'Entity': 'Asia',
#   'Code': nan,
#   'Year': 1995,
#   'Renewables (% equivalent primary energy)': 5.271553},
#  {'_id': ObjectId('680625e5f5024b2c90d00fec'),
#   'Entity': 'Asia',
#   'Code': nan,
#   'Year': 1996,
#   'Renewables (% equivalent primary energy)': 5.018597},
#  {'_id': ObjectId('680625e5f5024b2c90d00fed'),
#   'Entity': 'Asia',
#   'Code': nan,
#   'Year': 1997,
#   'Renewables (% equivalent primary energy)': 4.8939986},
#  {'_id': ObjectId('680625e5f5024b2c90d00fee'),
#   'Entity': 'Asia',
#   'Code': nan,
#   'Year': 1998,
#   'Renewables (% equivalent primary energy)': 5.178817},
#  {'_id': ObjectId('680625e5f5024b2c90d00fef'),
#   'Entity': 'Asia',
#   'Code': nan,
#   'Year': 1999,
#   'Renewables (% equivalent primary energy)': 4.9296236},
#  {'_id': ObjectId('680625e5f5024b2c90d00ff0'),
#   'Entity': 'Asia',
#   'Code': nan,
#   'Year': 2000,
#   'Renewables (% equivalent primary energy)': 4.9015436},
#  {'_id': ObjectId('680625e5f5024b2c90d00ff1'),
#   'Entity': 'Asia',
#   'Code': nan,
#   'Year': 2001,
#   'Renewables (% equivalent primary energy)': 5.0736527},
#  {'_id': ObjectId('680625e5f5024b2c90d00ff2'),
#   'Entity': 'Asia',
#   'Code': nan,
#   'Year': 2002,
#   'Renewables (% equivalent primary energy)': 4.9854317},
#  {'_id': ObjectId('680625e5f5024b2c90d00ff3'),
#   'Entity': 'Asia',
#   'Code': nan,
#   'Year': 2003,
#   'Renewables (% equivalent primary energy)': 4.7931614},
#  {'_id': ObjectId('680625e5f5024b2c90d00ff4'),
#   'Entity': 'Asia',
#   'Code': nan,
#   'Year': 2004,
#   'Renewables (% equivalent primary energy)': 5.0985446},
#  {'_id': ObjectId('680625e5f5024b2c90d00ff5'),
#   'Entity': 'Asia',
#   'Code': nan,
#   'Year': 2005,
#   'Renewables (% equivalent primary energy)': 4.9199796},
#  {'_id': ObjectId('680625e5f5024b2c90d00ff6'),
#   'Entity': 'Asia',
#   'Code': nan,
#   'Year': 2006,
#   'Renewables (% equivalent primary energy)': 5.117429},
#  {'_id': ObjectId('680625e5f5024b2c90d00ff7'),
#   'Entity': 'Asia',
#   'Code': nan,
#   'Year': 2007,
#   'Renewables (% equivalent primary energy)': 5.0853057},
#  {'_id': ObjectId('680625e5f5024b2c90d00ff8'),
#   'Entity': 'Asia',
#   'Code': nan,
#   'Year': 2008,
#   'Renewables (% equivalent primary energy)': 5.605236},
#  {'_id': ObjectId('680625e5f5024b2c90d00ff9'),
#   'Entity': 'Asia',
#   'Code': nan,
#   'Year': 2009,
#   'Renewables (% equivalent primary energy)': 5.458485},
#  {'_id': ObjectId('680625e5f5024b2c90d00ffa'),
#   'Entity': 'Asia',
#   'Code': nan,
#   'Year': 2010,
#   'Renewables (% equivalent primary energy)': 5.9468226},
#  {'_id': ObjectId('680625e5f5024b2c90d00ffb'),
#   'Entity': 'Asia',
#   'Code': nan,
#   'Year': 2011,
#   'Renewables (% equivalent primary energy)': 5.8778787},
#  {'_id': ObjectId('680625e5f5024b2c90d00ffc'),
#   'Entity': 'Asia',
#   'Code': nan,
#   'Year': 2012,
#   'Renewables (% equivalent primary energy)': 6.4778247},
#  {'_id': ObjectId('680625e5f5024b2c90d00ffd'),
#   'Entity': 'Asia',
#   'Code': nan,
#   'Year': 2013,
#   'Renewables (% equivalent primary energy)': 6.987413},
#  {'_id': ObjectId('680625e5f5024b2c90d00ffe'),
#   'Entity': 'Asia',
#   'Code': nan,
#   'Year': 2014,
#   'Renewables (% equivalent primary energy)': 7.551866},
#  {'_id': ObjectId('680625e5f5024b2c90d00fff'),
#   'Entity': 'Asia',
#   'Code': nan,
#   'Year': 2015,
#   'Renewables (% equivalent primary energy)': 7.908183},
#  {'_id': ObjectId('680625e5f5024b2c90d01000'),
#   'Entity': 'Asia',
#   'Code': nan,
#   'Year': 2016,
#   'Renewables (% equivalent primary energy)': 8.438702},
#  {'_id': ObjectId('680625e5f5024b2c90d01001'),
#   'Entity': 'Asia',
#   'Code': nan,
#   'Year': 2017,
#   'Renewables (% equivalent primary energy)': 8.845372},
#  {'_id': ObjectId('680625e5f5024b2c90d01002'),
#   'Entity': 'Asia',
#   'Code': nan,
#   'Year': 2018,
#   'Renewables (% equivalent primary energy)': 9.349624},
#  {'_id': ObjectId('680625e5f5024b2c90d01003'),
#   'Entity': 'Asia',
#   'Code': nan,
#   'Year': 2019,
#   'Renewables (% equivalent primary energy)': 10.002659},
#  {'_id': ObjectId('680625e5f5024b2c90d01004'),
#   'Entity': 'Asia',
#   'Code': nan,
#   'Year': 2020,
#   'Renewables (% equivalent primary energy)': 10.741154},
#  {'_id': ObjectId('680625e5f5024b2c90d01005'),
#   'Entity': 'Asia',
#   'Code': nan,
#   'Year': 2021,
#   'Renewables (% equivalent primary energy)': 11.2254095},
#  {'_id': ObjectId('680625e5f5024b2c90d01006'),
#   'Entity': 'Asia',
#   'Code': nan,
#   'Year': 2022,
#   'Renewables (% equivalent primary energy)': 11.969987},
#  {'_id': ObjectId('680625e5f5024b2c90d01007'),
#   'Entity': 'Asia',
#   'Code': nan,
#   'Year': 2023,
#   'Renewables (% equivalent primary energy)': 12.191386},
#  {'_id': ObjectId('680625e5f5024b2c90d01008'),
#   'Entity': 'Asia Pacific (EI)',
#   'Code': nan,
#   'Year': 1965,
#   'Renewables (% equivalent primary energy)': 8.879346},
#  {'_id': ObjectId('680625e5f5024b2c90d01009'),
#   'Entity': 'Asia Pacific (EI)',
#   'Code': nan,
#   'Year': 1966,
#   'Renewables (% equivalent primary energy)': 8.41833},
#  {'_id': ObjectId('680625e5f5024b2c90d0100a'),
#   'Entity': 'Asia Pacific (EI)',
#   'Code': nan,
#   'Year': 1967,
#   'Renewables (% equivalent primary energy)': 7.6206317},
#  {'_id': ObjectId('680625e5f5024b2c90d0100b'),
#   'Entity': 'Asia Pacific (EI)',
#   'Code': nan,
#   'Year': 1968,
#   'Renewables (% equivalent primary energy)': 7.814885},
#  {'_id': ObjectId('680625e5f5024b2c90d0100c'),
#   'Entity': 'Asia Pacific (EI)',
#   'Code': nan,
#   'Year': 1969,
# ...
#   'Entity': 'Central America (EI)',
#   'Code': nan,
#   'Year': 1976,
#   'Renewables (% equivalent primary energy)': 13.12191},
#  {'_id': ObjectId('680625e5f5024b2c90d01269'),
#   'Entity': 'Central America (EI)',
#   'Code': nan,
#   'Year': 1977,
#   'Renewables (% equivalent primary energy)': 12.341241},
#  {'_id': ObjectId('680625e5f5024b2c90d0126a'),
#   'Entity': 'Central America (EI)',
#   'Code': nan,
#   'Year': 1978,
#   'Renewables (% equivalent primary energy)': 15.349611},
#  {'_id': ObjectId('680625e5f5024b2c90d0126b'),
#   'Entity': 'Central America (EI)',
#   'Code': nan,
#   'Year': 1979,
#   'Renewables (% equivalent primary energy)': 17.265028},
#  {'_id': ObjectId('680625e5f5024b2c90d0126c'),
#   'Entity': 'Central America (EI)',
#   'Code': nan,
#   'Year': 1980,
#   'Renewables (% equivalent primary energy)': 20.214928},
#  {'_id': ObjectId('680625e5f5024b2c90d0126d'),
#   'Entity': 'Central America (EI)',
#   'Code': nan,
#   'Year': 1981,
#   'Renewables (% equivalent primary energy)': 22.399574},
#  {'_id': ObjectId('680625e5f5024b2c90d0126e'),
#   'Entity': 'Central America (EI)',
#   'Code': nan,
#   'Year': 1982,
#   'Renewables (% equivalent primary energy)': 22.183714},
#  {'_id': ObjectId('680625e5f5024b2c90d0126f'),
#   'Entity': 'Central America (EI)',
#   'Code': nan,
#   'Year': 1983,
#   'Renewables (% equivalent primary energy)': 23.578016},
#  {'_id': ObjectId('680625e5f5024b2c90d01270'),
#   'Entity': 'Central America (EI)',
#   'Code': nan,
#   'Year': 1984,
#   'Renewables (% equivalent primary energy)': 25.592047},
#  {'_id': ObjectId('680625e5f5024b2c90d01271'),
#   'Entity': 'Central America (EI)',
#   'Code': nan,
#   'Year': 1985,
#   'Renewables (% equivalent primary energy)': 26.786247},
#  {'_id': ObjectId('680625e5f5024b2c90d01272'),
#   'Entity': 'Central America (EI)',
#   'Code': nan,
#   'Year': 1986,
#   'Renewables (% equivalent primary energy)': 29.564842},
#  {'_id': ObjectId('680625e5f5024b2c90d01273'),
#   'Entity': 'Central America (EI)',
#   'Code': nan,
#   'Year': 1987,
#   'Renewables (% equivalent primary energy)': 28.886547},
#  {'_id': ObjectId('680625e5f5024b2c90d01274'),
#   'Entity': 'Central America (EI)',
#   'Code': nan,
#   'Year': 1988,
#   'Renewables (% equivalent primary energy)': 30.695482},
#  {'_id': ObjectId('680625e5f5024b2c90d01275'),
#   'Entity': 'Central America (EI)',
#   'Code': nan,
#   'Year': 1989,
#   'Renewables (% equivalent primary energy)': 31.725052},
#  {'_id': ObjectId('680625e5f5024b2c90d01276'),
#   'Entity': 'Central America (EI)',
#   'Code': nan,
#   'Year': 1990,
#   'Renewables (% equivalent primary energy)': 32.043663},
#  {'_id': ObjectId('680625e5f5024b2c90d01277'),
#   'Entity': 'Central America (EI)',
#   'Code': nan,
#   'Year': 1991,
#   'Renewables (% equivalent primary energy)': 29.83178},
#  {'_id': ObjectId('680625e5f5024b2c90d01278'),
#   'Entity': 'Central America (EI)',
#   'Code': nan,
#   'Year': 1992,
#   'Renewables (% equivalent primary energy)': 27.12252},
#  {'_id': ObjectId('680625e5f5024b2c90d01279'),
#   'Entity': 'Central America (EI)',
#   'Code': nan,
#   'Year': 1993,
#   'Renewables (% equivalent primary energy)': 27.521982},
#  {'_id': ObjectId('680625e5f5024b2c90d0127a'),
#   'Entity': 'Central America (EI)',
#   'Code': nan,
#   'Year': 1994,
#   'Renewables (% equivalent primary energy)': 25.153784},
#  {'_id': ObjectId('680625e5f5024b2c90d0127b'),
#   'Entity': 'Central America (EI)',
#   'Code': nan,
#   'Year': 1995,
#   'Renewables (% equivalent primary energy)': 23.175493},
#  {'_id': ObjectId('680625e5f5024b2c90d0127c'),
#   'Entity': 'Central America (EI)',
#   'Code': nan,
#   'Year': 1996,
#   'Renewables (% equivalent primary energy)': 25.864536},
#  {'_id': ObjectId('680625e5f5024b2c90d0127d'),
#   'Entity': 'Central America (EI)',
#   'Code': nan,
#   'Year': 1997,
#   'Renewables (% equivalent primary energy)': 24.05491},
#  {'_id': ObjectId('680625e5f5024b2c90d0127e'),
#   'Entity': 'Central America (EI)',
#   'Code': nan,
#   'Year': 1998,
#   'Renewables (% equivalent primary energy)': 21.420517},
#  {'_id': ObjectId('680625e5f5024b2c90d0127f'),
#   'Entity': 'Central America (EI)',
#   'Code': nan,
#   'Year': 1999,
#   'Renewables (% equivalent primary energy)': 24.960342},
#  {'_id': ObjectId('680625e5f5024b2c90d01280'),
#   'Entity': 'Central America (EI)',
#   'Code': nan,
#   'Year': 2000,
#   'Renewables (% equivalent primary energy)': 25.19626},
#  {'_id': ObjectId('680625e5f5024b2c90d01281'),
#   'Entity': 'Central America (EI)',
#   'Code': nan,
#   'Year': 2001,
#   'Renewables (% equivalent primary energy)': 22.390955},
#  {'_id': ObjectId('680625e5f5024b2c90d01282'),
#   'Entity': 'Central America (EI)',
#   'Code': nan,
#   'Year': 2002,
#   'Renewables (% equivalent primary energy)': 23.148567},
#  {'_id': ObjectId('680625e5f5024b2c90d01283'),
#   'Entity': 'Central America (EI)',
#   'Code': nan,
#   'Year': 2003,
#   'Renewables (% equivalent primary energy)': 23.086876},
#  {'_id': ObjectId('680625e5f5024b2c90d01284'),
#   'Entity': 'Central America (EI)',
#   'Code': nan,
#   'Year': 2004,
#   'Renewables (% equivalent primary energy)': 23.529451},
#  {'_id': ObjectId('680625e5f5024b2c90d01285'),
#   'Entity': 'Central America (EI)',
#   'Code': nan,
#   'Year': 2005,
#   'Renewables (% equivalent primary energy)': 24.86708},
#  {'_id': ObjectId('680625e5f5024b2c90d01286'),
#   'Entity': 'Central America (EI)',
#   'Code': nan,
#   'Year': 2006,
#   'Renewables (% equivalent primary energy)': 24.72052},
#  {'_id': ObjectId('680625e5f5024b2c90d01287'),
#   'Entity': 'Central America (EI)',
#   'Code': nan,
#   'Year': 2007,
#   'Renewables (% equivalent primary energy)': 24.016212},
#  {'_id': ObjectId('680625e5f5024b2c90d01288'),
#   'Entity': 'Central America (EI)',
#   'Code': nan,
#   'Year': 2008,
#   'Renewables (% equivalent primary energy)': 25.384161},
#  {'_id': ObjectId('680625e5f5024b2c90d01289'),
#   'Entity': 'Central America (EI)',
#   'Code': nan,
#   'Year': 2009,
#   'Renewables (% equivalent primary energy)': 25.172054},
#  {'_id': ObjectId('680625e5f5024b2c90d0128a'),
#   'Entity': 'Central America (EI)',
#   'Code': nan,
#   'Year': 2010,
#   'Renewables (% equivalent primary energy)': 27.074661},
#  {'_id': ObjectId('680625e5f5024b2c90d0128b'),
#   'Entity': 'Central America (EI)',
#   'Code': nan,
#   'Year': 2011,
#   'Renewables (% equivalent primary energy)': 26.338593},
#  {'_id': ObjectId('680625e5f5024b2c90d0128c'),
#   'Entity': 'Central America (EI)',
#   'Code': nan,
#   'Year': 2012,
#   'Renewables (% equivalent primary energy)': 27.493683},
#  {'_id': ObjectId('680625e5f5024b2c90d0128d'),
#   'Entity': 'Central America (EI)',
#   'Code': nan,
#   'Year': 2013,
#   'Renewables (% equivalent primary energy)': 27.202362},
#  {'_id': ObjectId('680625e5f5024b2c90d0128e'),
#   'Entity': 'Central America (EI)',
#   'Code': nan,
#   'Year': 2014,
#   'Renewables (% equivalent primary energy)': 27.154976},
#  {'_id': ObjectId('680625e5f5024b2c90d0128f'),
#   'Entity': 'Central America (EI)',
#   'Code': nan,
#   'Year': 2015,
#   'Renewables (% equivalent primary energy)': 26.713547},
#  {'_id': ObjectId('680625e5f5024b2c90d01290'),
#   'Entity': 'Central America (EI)',
#   'Code': nan,
#   'Year': 2016,
#   'Renewables (% equivalent primary energy)': 26.798523},
#  {'_id': ObjectId('680625e5f5024b2c90d01291'),
#   'Entity': 'Central America (EI)',
#   'Code': nan,
#   'Year': 2017,
#   'Renewables (% equivalent primary energy)': 28.610437},
#  {'_id': ObjectId('680625e5f5024b2c90d01292'),
#   'Entity': 'Central America (EI)',
#   'Code': nan,
#   'Year': 2018,
#   'Renewables (% equivalent primary energy)': 29.266819},
#  {'_id': ObjectId('680625e5f5024b2c90d01293'),
#   'Entity': 'Central America (EI)',
#   'Code': nan,
#   'Year': 2019,
#   'Renewables (% equivalent primary energy)': 25.451958},
#  {'_id': ObjectId('680625e5f5024b2c90d01294'),
#   'Entity': 'Central America (EI)',
#   'Code': nan,
#   'Year': 2020,
#   'Renewables (% equivalent primary energy)': 32.487274},
#  {'_id': ObjectId('680625e5f5024b2c90d01295'),
#   'Entity': 'Central America (EI)',
#   'Code': nan,
#   'Year': 2021,
#   'Renewables (% equivalent primary energy)': 31.537489},
#  {'_id': ObjectId('680625e5f5024b2c90d01296'),
#   'Entity': 'Central America (EI)',
#   'Code': nan,
#   'Year': 2022,
#   'Renewables (% equivalent primary energy)': 30.899012},
#  {'_id': ObjectId('680625e5f5024b2c90d01297'),
#   'Entity': 'Central America (EI)',
#   'Code': nan,
#   'Year': 2023,
#   'Renewables (% equivalent primary energy)': 26.829386},
#  {'_id': ObjectId('680625e5f5024b2c90d01298'),
#   'Entity': 'Chile',
#   'Code': 'CHL',
#   'Year': 1965,
#   'Renewables (% equivalent primary energy)': 16.141762},
#  {'_id': ObjectId('680625e5f5024b2c90d01299'),
#   'Entity': 'Chile',
#   'Code': 'CHL',
#   'Year': 1966,
#   'Renewables (% equivalent primary energy)': 15.867013},
#  {'_id': ObjectId('680625e5f5024b2c90d0129a'),
#   'Entity': 'Chile',
#   'Code': 'CHL',
#   'Year': 1967,
#   'Renewables (% equivalent primary energy)': 15.8887},
#  {'_id': ObjectId('680625e5f5024b2c90d0129b'),
#   'Entity': 'Chile',
#   'Code': 'CHL',
#   'Year': 1968,
#   'Renewables (% equivalent primary energy)': 13.367759},
#  {'_id': ObjectId('680625e5f5024b2c90d0129c'),
#   'Entity': 'Chile',
#   'Code': 'CHL',
#   'Year': 1969,
#   'Renewables (% equivalent primary energy)': 13.999327},
#  {'_id': ObjectId('680625e5f5024b2c90d0129d'),
#   'Entity': 'Chile',
#   'Code': 'CHL',
#   'Year': 1970,
#   'Renewables (% equivalent primary energy)': 14.19122},
#  {'_id': ObjectId('680625e5f5024b2c90d0129e'),
#   'Entity': 'Chile',
#   'Code': 'CHL',
#   'Year': 1971,
#   'Renewables (% equivalent primary energy)': 14.860414},
#  {'_id': ObjectId('680625e5f5024b2c90d0129f'),
#   'Entity': 'Chile',
#   'Code': 'CHL',
#   'Year': 1972,
#   'Renewables (% equivalent primary energy)': 17.308092},
#  {'_id': ObjectId('680625e5f5024b2c90d012a0'),
#   'Entity': 'Chile',
#   'Code': 'CHL',
#   'Year': 1973,
#   'Renewables (% equivalent primary energy)': 17.450201},
#  {'_id': ObjectId('680625e5f5024b2c90d012a1'),
#   'Entity': 'Chile',
#   'Code': 'CHL',
#   'Year': 1974,
#   'Renewables (% equivalent primary energy)': 19.770317},
#  {'_id': ObjectId('680625e5f5024b2c90d012a2'),
#   'Entity': 'Chile',
#   'Code': 'CHL',
#   'Year': 1975,
#   'Renewables (% equivalent primary energy)': 21.942268},
#  {'_id': ObjectId('680625e5f5024b2c90d012a3'),
#   'Entity': 'Chile',
#   'Code': 'CHL',
#   'Year': 1976,
#   'Renewables (% equivalent primary energy)': 21.900364},
#  {'_id': ObjectId('680625e5f5024b2c90d012a4'),
#   'Entity': 'Chile',
#   'Code': 'CHL',
#   'Year': 1977,
#   'Renewables (% equivalent primary energy)': 22.105398},
#  {'_id': ObjectId('680625e5f5024b2c90d012a5'),
#   'Entity': 'Chile',
#   'Code': 'CHL',
#   'Year': 1978,
#   'Renewables (% equivalent primary energy)': 22.151817},
#  {'_id': ObjectId('680625e5f5024b2c90d012a6'),
#   'Entity': 'Chile',
#   'Code': 'CHL',
#   'Year': 1979,
#   'Renewables (% equivalent primary energy)': 21.552887},
#  {'_id': ObjectId('680625e5f5024b2c90d012a7'),
#   'Entity': 'Chile',
#   'Code': 'CHL',
#   'Year': 1980,
#   'Renewables (% equivalent primary energy)': 22.069942},
#  {'_id': ObjectId('680625e5f5024b2c90d012a8'),
#   'Entity': 'Chile',
#   'Code': 'CHL',
#   'Year': 1981,
#   'Renewables (% equivalent primary energy)': 22.72726},
#  {'_id': ObjectId('680625e5f5024b2c90d012a9'),
#   'Entity': 'Chile',
#   'Code': 'CHL',
#   'Year': 1982,
#   'Renewables (% equivalent primary energy)': 26.627869},
#  {'_id': ObjectId('680625e5f5024b2c90d012aa'),
#   'Entity': 'Chile',
#   'Code': 'CHL',
#   'Year': 1983,
#   'Renewables (% equivalent primary energy)': 27.825817},
#  {'_id': ObjectId('680625e5f5024b2c90d012ab'),
#   'Entity': 'Chile',
#   'Code': 'CHL',
#   'Year': 1984,
#   'Renewables (% equivalent primary energy)': 27.770302},
#  {'_id': ObjectId('680625e5f5024b2c90d012ac'),
#   'Entity': 'Chile',
#   'Code': 'CHL',
#   'Year': 1985,
#   'Renewables (% equivalent primary energy)': 30.351582},
#  {'_id': ObjectId('680625e5f5024b2c90d012ad'),
#   'Entity': 'Chile',
#   'Code': 'CHL',
#   'Year': 1986,
#   'Renewables (% equivalent primary energy)': 31.423769},
#  {'_id': ObjectId('680625e5f5024b2c90d012ae'),
#   'Entity': 'Chile',
#   'Code': 'CHL',
#   'Year': 1987,
#   'Renewables (% equivalent primary energy)': 32.36392},
#  {'_id': ObjectId('680625e5f5024b2c90d012af'),
#   'Entity': 'Chile',
#   'Code': 'CHL',
#   'Year': 1988,
#   'Renewables (% equivalent primary energy)': 28.551182},
#  {'_id': ObjectId('680625e5f5024b2c90d012b0'),
#   'Entity': 'Chile',
#   'Code': 'CHL',
#   'Year': 1989,
#   'Renewables (% equivalent primary energy)': 21.783056},
#  {'_id': ObjectId('680625e5f5024b2c90d012b1'),
#   'Entity': 'Chile',
#   'Code': 'CHL',
#   'Year': 1990,
#   'Renewables (% equivalent primary energy)': 18.957916},
#  {'_id': ObjectId('680625e5f5024b2c90d012b2'),
#   'Entity': 'Chile',
#   'Code': 'CHL',
#   'Year': 1991,
#   'Renewables (% equivalent primary energy)': 24.08466},
#  {'_id': ObjectId('680625e5f5024b2c90d012b3'),
#   'Entity': 'Chile',
#   'Code': 'CHL',
#   'Year': 1992,
#   'Renewables (% equivalent primary energy)': 28.355387},
#  {'_id': ObjectId('680625e5f5024b2c90d012b4'),
#   'Entity': 'Chile',
#   'Code': 'CHL',
#   'Year': 1993,
#   'Renewables (% equivalent primary energy)': 27.529266},
#  {'_id': ObjectId('680625e5f5024b2c90d012b5'),
#   'Entity': 'Chile',
#   'Code': 'CHL',
#   'Year': 1994,
#   'Renewables (% equivalent primary energy)': 25.954521},
#  {'_id': ObjectId('680625e5f5024b2c90d012b6'),
#   'Entity': 'Chile',
#   'Code': 'CHL',
#   'Year': 1995,
#   'Renewables (% equivalent primary energy)': 26.028479},
#  {'_id': ObjectId('680625e5f5024b2c90d012b7'),
#   'Entity': 'Chile',
#   'Code': 'CHL',
#   'Year': 1996,
#   'Renewables (% equivalent primary energy)': 22.5519},
#  {'_id': ObjectId('680625e5f5024b2c90d012b8'),
#   'Entity': 'Chile',
#   'Code': 'CHL',
#   'Year': 1997,
#   'Renewables (% equivalent primary energy)': 21.909548},
#  {'_id': ObjectId('680625e5f5024b2c90d012b9'),
#   'Entity': 'Chile',
#   'Code': 'CHL',
#   'Year': 1998,
#   'Renewables (% equivalent primary energy)': 18.059258},
#  {'_id': ObjectId('680625e5f5024b2c90d012ba'),
#   'Entity': 'Chile',
#   'Code': 'CHL',
#   'Year': 1999,
#   'Renewables (% equivalent primary energy)': 15.275814},
#  {'_id': ObjectId('680625e5f5024b2c90d012bb'),
#   'Entity': 'Chile',
#   'Code': 'CHL',
#   'Year': 2000,
#   'Renewables (% equivalent primary energy)': 19.783125},
#  {'_id': ObjectId('680625e5f5024b2c90d012bc'),
#   'Entity': 'Chile',
#   'Code': 'CHL',
#   'Year': 2001,
#   'Renewables (% equivalent primary energy)': 22.047363},
#  {'_id': ObjectId('680625e5f5024b2c90d012bd'),
#   'Entity': 'Chile',
#   'Code': 'CHL',
#   'Year': 2002,
#   'Renewables (% equivalent primary energy)': 22.87545},
#  {'_id': ObjectId('680625e5f5024b2c90d012be'),
#   'Entity': 'Chile',
#   'Code': 'CHL',
#   'Year': 2003,
#   'Renewables (% equivalent primary energy)': 22.010805},
#  {'_id': ObjectId('680625e5f5024b2c90d012bf'),
#   'Entity': 'Chile',
#   'Code': 'CHL',
#   'Year': 2004,
#   'Renewables (% equivalent primary energy)': 19.43779},
#  {'_id': ObjectId('680625e5f5024b2c90d012c0'),
#   'Entity': 'Chile',
#   'Code': 'CHL',
#   'Year': 2005,
#   'Renewables (% equivalent primary energy)': 22.099463},
#  {'_id': ObjectId('680625e5f5024b2c90d012c1'),
#   'Entity': 'Chile',
#   'Code': 'CHL',
#   'Year': 2006,
#   'Renewables (% equivalent primary energy)': 22.957874},
#  {'_id': ObjectId('680625e5f5024b2c90d012c2'),
#   'Entity': 'Chile',
#   'Code': 'CHL',
#   'Year': 2007,
#   'Renewables (% equivalent primary energy)': 19.440195},
#  {'_id': ObjectId('680625e5f5024b2c90d012c3'),
#   'Entity': 'Chile',
#   'Code': 'CHL',
#   'Year': 2008,
#   'Renewables (% equivalent primary energy)': 21.59478},
#  {'_id': ObjectId('680625e5f5024b2c90d012c4'),
#   'Entity': 'Chile',
#   'Code': 'CHL',
#   'Year': 2009,
#   'Renewables (% equivalent primary energy)': 22.96064},
#  {'_id': ObjectId('680625e5f5024b2c90d012c5'),
#   'Entity': 'Chile',
#   'Code': 'CHL',
#   'Year': 2010,
#   'Renewables (% equivalent primary energy)': 19.835663},
#  {'_id': ObjectId('680625e5f5024b2c90d012c6'),
#   'Entity': 'Chile',
#   'Code': 'CHL',
#   'Year': 2011,
#   'Renewables (% equivalent primary energy)': 18.481121},
#  {'_id': ObjectId('680625e5f5024b2c90d012c7'),
#   'Entity': 'Chile',
#   'Code': 'CHL',
#   'Year': 2012,
#   'Renewables (% equivalent primary energy)': 18.747072},
#  {'_id': ObjectId('680625e5f5024b2c90d012c8'),
#   'Entity': 'Chile',
#   'Code': 'CHL',
#   'Year': 2013,
#   'Renewables (% equivalent primary energy)': 18.79665},
#  ...]

# %%
renewable_energy_df = pd.DataFrame(renewable_list_cursor)

# %%
renewable_energy_df
# Out:
#                            _id  Entity      Code  Year  \
# 0     680625e5f5024b2c90d00ee1  Africa       NaN  1965
# 1     680625e5f5024b2c90d00ee2  Africa       NaN  1966
# 2     680625e5f5024b2c90d00ee3  Africa       NaN  1967
# 3     680625e5f5024b2c90d00ee4  Africa       NaN  1968
# 4     680625e5f5024b2c90d00ee5  Africa       NaN  1969
# ...                        ...     ...       ...   ...
# 4898  680625e5f5024b2c90d02203   World  OWID_WRL  2019
# 4899  680625e5f5024b2c90d02204   World  OWID_WRL  2020
# 4900  680625e5f5024b2c90d02205   World  OWID_WRL  2021
# 4901  680625e5f5024b2c90d02206   World  OWID_WRL  2022
# 4902  680625e5f5024b2c90d02207   World  OWID_WRL  2023
#
#       Renewables (% equivalent primary energy)
# 0                                     5.740281
# 1                                     6.113969
# 2                                     6.316580
# 3                                     6.994845
# 4                                     7.943916
# ...                                        ...
# 4898                                 12.228147
# 4899                                 13.404395
# 4900                                 13.469198
# 4901                                 14.119935
# 4902                                 14.562141
#
# [4903 rows x 5 columns]

# %% [markdown]
# ### Data Transformation

# %%
renewable_energy_df.drop(columns=["Code"], inplace=True, axis=1)

# %%
renewable_energy_df.drop(columns=["_id"], inplace=True, axis=1)

# %%
renewable_energy_df.rename(columns={"Entity": "Area"}, inplace=True)

# %%
renewable_energy_df.rename(columns={'Renewables (% equivalent primary energy)': 'Renewable_Energy_Share'}, inplace=True)

# %%
renewable_energy_df.head()
# Out:
#      Area  Year  Renewable_Energy_Share
# 0  Africa  1965                5.740281
# 1  Africa  1966                6.113969
# 2  Africa  1967                6.316580
# 3  Africa  1968                6.994845
# 4  Africa  1969                7.943916

# %% [markdown]
# ### Loading Transformed Data to PostgreSQL

# %%
pgconn=psycopg2.connect(host="localhost", database="co2_renew_life", user="postgres", password="admin")

# %%
pgcursor=pgconn.cursor()

# %%
from psycopg2.extensions import ISOLATION_LEVEL_AUTOCOMMIT

pgconn.set_isolation_level(ISOLATION_LEVEL_AUTOCOMMIT)

# %%
pgcursor.execute("CREATE TABLE IF NOT EXISTS renewable_energy (Area TEXT, Year INT, Renewable_Energy_Share FLOAT);")

# %%
from psycopg2.extras import execute_values

execute_values(pgcursor, "INSERT INTO renewable_energy (Area, Year, Renewable_Energy_Share) VALUES %s", renewable_energy_df.values.tolist())

# %%
pgconn.commit()

# %% [markdown]
# ### MongoDB Connection to fetch data and transformation

# %%
def check_mongodb_collection(client, db_name, collection_name):
    try:
        db = client[db_name]
        print(f"Connected to database: {db_name}")
        collections = db.list_collection_names()
        print(f"Collections in {db_name}: {collections}")
        
        if collection_name not in collections:
            print(f"Collection '{collection_name}' does not exist in {db_name}")
            return False
        
        collection = db[collection_name]
        doc_count = collection.count_documents({})
        print(f"Number of documents in {collection_name}: {doc_count}")
        
        if doc_count == 0:
            print(f"Collection '{collection_name}' is empty")
            return False
        
        sample_doc = collection.find_one()
        print(f"Sample document from {collection_name}: {sample_doc}")
        return True
    except Exception as e:
        print(f"Error accessing {db_name}/{collection_name}: {e}")
        return False


print("--- Processing Carbon Emissions Data ---")

try:
    client = pymongo.MongoClient("mongodb://localhost:27017/")
    print("MongoDB connection successful")
    print("Available databases:", client.list_database_names())
except Exception as e:
    print(f"Failed to connect to MongoDB: {e}")
    client = None

if client:
    if check_mongodb_collection(client, "co2_renew_life_db", "carbon_emissions"):
        db = client["co2_renew_life_db"]
        emissions_collection = db["carbon_emissions"]

        emissions_all_records = emissions_collection.find()
        emissions_list_cursor = list(emissions_all_records)
        print(f"Retrieved {len(emissions_list_cursor)} records from carbon_emissions")

        emissions_df = pd.DataFrame(emissions_list_cursor)

        if emissions_df.empty:
            print("Emissions DataFrame is empty")
        else:
            print("Emissions DataFrame shape:", emissions_df.shape)
            print("Emissions DataFrame columns:", emissions_df.columns)
            print("Emissions DataFrame missing values:\n", emissions_df.isnull().sum())
            print("Emissions DataFrame head:\n", emissions_df.head())

            if '_id' in emissions_df.columns:
                emissions_df.drop(columns=["_id"], inplace=True)
            if 'Code' in emissions_df.columns:
                emissions_df.drop(columns=["Code"], inplace=True)

            emissions_df.rename(columns={
                "Entity": "Area",
                "Year": "Year",
                "Annual CO₂ emissions (per capita)": "CO2_Emissions_Per_Capita"
            }, inplace=True)

            print("Cleaned Emissions DataFrame head:\n", emissions_df.head())
    else:
        print("Skipping emissions data processing due to empty or missing collection")
else:
    print("Skipping emissions data processing due to connection failure")
# Out:
# --- Processing Carbon Emissions Data ---
# MongoDB connection successful
# Available databases: ['admin', 'co2_renew_life_db', 'config', 'local']
# Connected to database: co2_renew_life_db
# Collections in co2_renew_life_db: ['renewable_energy', 'carbon_emissions', 'life_expectancy']
# Number of documents in carbon_emissions: 26182
# Sample document from carbon_emissions: {'_id': ObjectId('680625e5f5024b2c90cfa89b'), 'Entity': 'Afghanistan', 'Code': 'AFG', 'Year': 1949, 'Annual CO₂ emissions (per capita)': 0.0019921463}
# Retrieved 26182 records from carbon_emissions
# Emissions DataFrame shape: (26182, 5)
# Emissions DataFrame columns: Index(['_id', 'Entity', 'Code', 'Year', 'Annual CO₂ emissions (per capita)'], dtype='object')
# Emissions DataFrame missing values:
#  _id                                     0
# Entity                                  0
# Code                                 3287
# Year                                    0
# Annual CO₂ emissions (per capita)       0
# dtype: int64
# Emissions DataFrame head:
#                          _id       Entity Code  Year  \
# 0  680625e5f5024b2c90cfa89b  Afghanistan  AFG  1949
# 1  680625e5f5024b2c90cfa89c  Afghanistan  AFG  1950
# 2  680625e5f5024b2c90cfa89d  Afghanistan  AFG  1951
# 3  680625e5f5024b2c90cfa89e  Afghanistan  AFG  1952
# 4  680625e5f5024b2c90cfa89f  Afghanistan  AFG  1953
#
#    Annual CO₂ emissions (per capita)
# 0                           0.001992
# 1                           0.010837
# 2                           0.011625
# 3                           0.011468
# 4                           0.013123
# Cleaned Emissions DataFrame head:
#            Area  Year  CO2_Emissions_Per_Capita
# 0  Afghanistan  1949                  0.001992
# 1  Afghanistan  1950                  0.010837
# 2  Afghanistan  1951                  0.011625
# 3  Afghanistan  1952                  0.011468
# 4  Afghanistan  1953                  0.013123

# %%
emissions_df.head()
# Out:
#           Area  Year  CO2_Emissions_Per_Capita
# 0  Afghanistan  1949                  0.001992
# 1  Afghanistan  1950                  0.010837
# 2  Afghanistan  1951                  0.011625
# 3  Afghanistan  1952                  0.011468
# 4  Afghanistan  1953                  0.013123

# %% [markdown]
# ### Loading Transformed Data to PostgreSQL

# %%
pgconn=psycopg2.connect(host="localhost", database="co2_renew_life", user="postgres", password="admin")

# %%
pgcursor=pgconn.cursor()

# %%
from psycopg2.extensions import ISOLATION_LEVEL_AUTOCOMMIT

pgconn.set_isolation_level(ISOLATION_LEVEL_AUTOCOMMIT)

# %%
pgcursor.execute("CREATE TABLE IF NOT EXISTS carbon_emissions (Area TEXT, Year INT, CO2_Emissions_Per_Capita FLOAT);")

# %%
from psycopg2.extras import execute_values

execute_values(pgcursor, "INSERT INTO carbon_emissions (Area, Year, CO2_Emissions_Per_Capita) VALUES %s", emissions_df.values.tolist())

# %%
pgconn.commit()

# %% [markdown]
# ### MongoDB Connection to fetch data and transformation

# %%
if client:
    if check_mongodb_collection(client, "co2_renew_life_db", "life_expectancy"):
        db = client["co2_renew_life_db"]
        life_expectancy_collection = db["life_expectancy"]

        life_expectancy_all_records = life_expectancy_collection.find()
        life_expectancy_list_cursor = list(life_expectancy_all_records)
        print(f"Retrieved {len(life_expectancy_list_cursor)} records from life_expectancy")

        life_expectancy_df = pd.DataFrame(life_expectancy_list_cursor)

        if life_expectancy_df.empty:
            print("Life Expectancy DataFrame is empty")
        else:
            print("Life Expectancy DataFrame shape:", life_expectancy_df.shape)
            print("Life Expectancy DataFrame columns:", life_expectancy_df.columns)
            print("Life Expectancy DataFrame missing values:\n", life_expectancy_df.isnull().sum())
            print("Life Expectancy DataFrame head:\n", life_expectancy_df.head())

            if '_id' in life_expectancy_df.columns:
                life_expectancy_df.drop(columns=["_id"], inplace=True)
            if 'Code' in life_expectancy_df.columns:
                life_expectancy_df.drop(columns=["Code"], inplace=True)

            life_expectancy_df.rename(columns={
                "Entity": "Area",
                "Year": "Year",
                "Period life expectancy at birth - Sex: total - Age: 0": "Life_Expectancy"
            }, inplace=True)

            print("Cleaned Life Expectancy DataFrame head:\n", life_expectancy_df.head())
    else:
        print("Skipping life expectancy data processing due to empty or missing collection")
else:
    print("Skipping life expectancy data processing due to connection failure")
# Out:
# Connected to database: co2_renew_life_db
# Collections in co2_renew_life_db: ['renewable_energy', 'carbon_emissions', 'life_expectancy']
# Number of documents in life_expectancy: 21565
# Sample document from life_expectancy: {'_id': ObjectId('680625e5f5024b2c90d02208'), 'Entity': 'Afghanistan', 'Code': 'AFG', 'Year': 1950, 'Period life expectancy at birth - Sex: total - Age: 0': 28.1563}
# Retrieved 21565 records from life_expectancy
# Life Expectancy DataFrame shape: (21565, 5)
# Life Expectancy DataFrame columns: Index(['_id', 'Entity', 'Code', 'Year',
#        'Period life expectancy at birth - Sex: total - Age: 0'],
#       dtype='object')
# Life Expectancy DataFrame missing values:
#  _id                                                         0
# Entity                                                      0
# Code                                                     1956
# Year                                                        0
# Period life expectancy at birth - Sex: total - Age: 0       0
# dtype: int64
# Life Expectancy DataFrame head:
#                          _id       Entity Code  Year  \
# 0  680625e5f5024b2c90d02208  Afghanistan  AFG  1950
# 1  680625e5f5024b2c90d02209  Afghanistan  AFG  1951
# 2  680625e5f5024b2c90d0220a  Afghanistan  AFG  1952
# 3  680625e5f5024b2c90d0220b  Afghanistan  AFG  1953
# 4  680625e5f5024b2c90d0220c  Afghanistan  AFG  1954
#
#    Period life expectancy at birth - Sex: total - Age: 0
# 0                                            28.1563
# 1                                            28.5836
# 2                                            29.0138
# 3                                            29.4521
# 4                                            29.6975
# Cleaned Life Expectancy DataFrame head:
#            Area  Year  Life_Expectancy
# 0  Afghanistan  1950          28.1563
# 1  Afghanistan  1951          28.5836
# 2  Afghanistan  1952          29.0138
# 3  Afghanistan  1953          29.4521
# 4  Afghanistan  1954          29.6975

# %%
life_expectancy_df.head()
# Out:
#           Area  Year  Life_Expectancy
# 0  Afghanistan  1950          28.1563
# 1  Afghanistan  1951          28.5836
# 2  Afghanistan  1952          29.0138
# 3  Afghanistan  1953          29.4521
# 4  Afghanistan  1954          29.6975

# %% [markdown]
# ### Loading Transformed Data to PostgreSQL

# %%
pgconn=psycopg2.connect(host="localhost", database="co2_renew_life", user="postgres", password="admin")

# %%
pgcursor=pgconn.cursor()

# %%
from psycopg2.extensions import ISOLATION_LEVEL_AUTOCOMMIT

pgconn.set_isolation_level(ISOLATION_LEVEL_AUTOCOMMIT)

# %%
pgcursor.execute("CREATE TABLE IF NOT EXISTS life_expectancy (Area TEXT, Year INT, Life_Expectancy FLOAT);")

# %%
from psycopg2.extras import execute_values

execute_values(pgcursor, "INSERT INTO life_expectancy (Area, Year, Life_Expectancy) VALUES %s", life_expectancy_df.values.tolist())

# %%
pgconn.commit()
